# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('BHHcj_data.csv', names=['REs', 'PrNd', 'La', 'Ce', 'Fe', 'Co', 'TM', 'B', 'PrNd_p', 'La_p', 'Ce_p', 'BH', 'Hcj', 'Sum'])
X = df.iloc[:, :11].values
y = df['BH'].values

test_data = pd.DataFrame()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
cv = KFold(n_splits=5, shuffle=True, random_state=38)

# %%
def abserr(y_pred, y_test):
    err = np.abs(y_pred - y_test)
    return err.mean()

# %%
##### Linear ######
clf = LinearRegression()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
r2_test = clf.score(X_test, y_test)
abs_test = abserr(y_pred, y_test)
print(r2_test, abs_test)
x0 = np.linspace(-2, 25, 100)
plt.plot(x0, x0, 'r')
plt.scatter(y_test, y_pred)
# Out:
# 0.720715235572 2.16965348956

# %%
clf = LinearRegression()
clf.fit(X, y)
y_pred = clf.predict(X_test)
r2_test = clf.score(X_test, y_test)
abs_test = abserr(y_pred, y_test)
print(r2_test, abs_test)
x0 = np.linspace(-2, 25, 100)
plt.plot(x0, x0, 'r')
plt.scatter(y_test, y_pred)
test_data['Linear'] = y_pred
# Out:
# 0.728895281535 2.13224690397

# %%
######## SVR ######
clf = SVR()
######## Range ########
C_range = 2 ** np.arange(0, 14)
gamma_range = 2 ** np.linspace(0, -10, 11)
tuned_parameters = dict(C=C_range, gamma=gamma_range)
######## Param #########


clf = GridSearchCV(estimator=clf, param_grid=tuned_parameters, cv=cv, n_jobs=-1)
clf.fit(X_train, y_train)

print("The best parameters are %s with a score of %0.5f, test_score: %0.5f" % (clf.best_params_, clf.best_score_, clf.score(X_test, y_test)))
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("r2: %0.4f, std: %0.03f for %r" % (mean, std, params))
print()
# Out:
# The best parameters are {'C': 4, 'gamma': 0.03125} with a score of 0.71754, test_score: 0.72126
#
# {'C': 4, 'gamma': 0.03125}
#
# Grid scores on development set:
#
# r2: 0.2004, std: 0.048 for {'C': 1, 'gamma': 1.0}
# r2: 0.3129, std: 0.053 for {'C': 1, 'gamma': 0.5}
# r2: 0.4340, std: 0.066 for {'C': 1, 'gamma': 0.25}
# r2: 0.5498, std: 0.063 for {'C': 1, 'gamma': 0.125}
# r2: 0.6276, std: 0.058 for {'C': 1, 'gamma': 0.0625}
# r2: 0.6644, std: 0.061 for {'C': 1, 'gamma': 0.03125}
# r2: 0.6721, std: 0.067 for {'C': 1, 'gamma': 0.015625}
# r2: 0.6583, std: 0.076 for {'C': 1, 'gamma': 0.0078125}
# r2: 0.6426, std: 0.079 for {'C': 1, 'gamma': 0.00390625}
# r2: 0.6176, std: 0.082 for {'C': 1, 'gamma': 0.001953125}
# r2: 0.5894, std: 0.084 for {'C': 1, 'gamma': 0.0009765625}
# r2: 0.2883, std: 0.050 for {'C': 2, 'gamma': 1.0}
# r2: 0.4011, std: 0.059 for {'C': 2, 'gamma': 0.5}
# r2: 0.5202, std: 0.068 for {'C': 2, 'gamma': 0.25}
# r2: 0.6130, std: 0.064 for {'C': 2, 'gamma': 0.125}
# r2: 0.6751, std: 0.058 for {'C': 2, 'gamma': 0.0625}
# r2: 0.6998, std: 0.059 for {'C': 2, 'gamma': 0.03125}
# r2: 0.6922, std: 0.065 for {'C': 2, 'gamma': 0.015625}
# r2: 0.6778, std: 0.075 for {'C': 2, 'gamma': 0.0078125}
# r2: 0.6619, std: 0.080 for {'C': 2, 'gamma': 0.00390625}
# r2: 0.6379, std: 0.080 for {'C': 2, 'gamma': 0.001953125}
# r2: 0.6154, std: 0.079 for {'C': 2, 'gamma': 0.0009765625}
# r2: 0.3515, std: 0.063 for {'C': 4, 'gamma': 1.0}
# r2: 0.4528, std: 0.059 for {'C': 4, 'gamma': 0.5}
# r2: 0.5595, std: 0.069 for {'C': 4, 'gamma': 0.25}
# r2: 0.6386, std: 0.062 for {'C': 4, 'gamma': 0.125}
# r2: 0.6919, std: 0.051 for {'C': 4, 'gamma': 0.0625}
# r2: 0.7175, std: 0.045 for {'C': 4, 'gamma': 0.03125}
# r2: 0.7040, std: 0.053 for {'C': 4, 'gamma': 0.015625}
# r2: 0.6849, std: 0.068 for {'C': 4, 'gamma': 0.0078125}
# r2: 0.6727, std: 0.078 for {'C': 4, 'gamma': 0.00390625}
# r2: 0.6579, std: 0.079 for {'C': 4, 'gamma': 0.001953125}
# r2: 0.6287, std: 0.082 for {'C': 4, 'gamma': 0.0009765625}
# r2: 0.3734, std: 0.070 for {'C': 8, 'gamma': 1.0}
# r2: 0.4735, std: 0.062 for {'C': 8, 'gamma': 0.5}
# r2: 0.5674, std: 0.065 for {'C': 8, 'gamma': 0.25}
# r2: 0.6377, std: 0.051 for {'C': 8, 'gamma': 0.125}
# r2: 0.6783, std: 0.039 for {'C': 8, 'gamma': 0.0625}
# r2: 0.7124, std: 0.032 for {'C': 8, 'gamma': 0.03125}
# r2: 0.7084, std: 0.036 for {'C': 8, 'gamma': 0.015625}
# r2: 0.6798, std: 0.058 for {'C': 8, 'gamma': 0.0078125}
# r2: 0.6718, std: 0.070 for {'C': 8, 'gamma': 0.00390625}
# r2: 0.6617, std: 0.080 for {'C': 8, 'gamma': 0.001953125}
# r2: 0.6511, std: 0.077 for {'C': 8, 'gamma': 0.0009765625}
# r2: 0.3736, std: 0.077 for {'C': 16, 'gamma': 1.0}
# r2: 0.4690, std: 0.079 for {'C': 16, 'gamma': 0.5}
# r2: 0.5548, std: 0.064 for {'C': 16, 'gamma': 0.25}
# r2: 0.6184, std: 0.049 for {'C': 16, 'gamma': 0.125}
# r2: 0.6647, std: 0.030 for {'C': 16, 'gamma': 0.0625}
# r2: 0.6908, std: 0.025 for {'C': 16, 'gamma': 0.03125}
# r2: 0.6933, std: 0.046 for {'C': 16, 'gamma': 0.015625}
# r2: 0.6748, std: 0.059 for {'C': 16, 'gamma': 0.0078125}
# r2: 0.6598, std: 0.075 for {'C': 16, 'gamma': 0.00390625}
# r2: 0.6621, std: 0.072 for {'C': 16, 'gamma': 0.001953125}
# r2: 0.6606, std: 0.080 for {'C': 16, 'gamma': 0.0009765625}
# r2: 0.3660, std: 0.072 for {'C': 32, 'gamma': 1.0}
# r2: 0.4623, std: 0.083 for {'C': 32, 'gamma': 0.5}
# r2: 0.5459, std: 0.070 for {'C': 32, 'gamma': 0.25}
# r2: 0.5946, std: 0.064 for {'C': 32, 'gamma': 0.125}
# r2: 0.6449, std: 0.050 for {'C': 32, 'gamma': 0.0625}
# r2: 0.6698, std: 0.024 for {'C': 32, 'gamma': 0.03125}
# r2: 0.6768, std: 0.056 for {'C': 32, 'gamma': 0.015625}
# r2: 0.6467, std: 0.110 for {'C': 32, 'gamma': 0.0078125}
# r2: 0.6439, std: 0.092 for {'C': 32, 'gamma': 0.00390625}
# r2: 0.6544, std: 0.074 for {'C': 32, 'gamma': 0.001953125}
# r2: 0.6569, std: 0.078 for {'C': 32, 'gamma': 0.0009765625}
# r2: 0.3626, std: 0.071 for {'C': 64, 'gamma': 1.0}
# r2: 0.4557, std: 0.090 for {'C': 64, 'gamma': 0.5}
# r2: 0.5327, std: 0.078 for {'C': 64, 'gamma': 0.25}
# r2: 0.5708, std: 0.062 for {'C': 64, 'gamma': 0.125}
# r2: 0.6139, std: 0.082 for {'C': 64, 'gamma': 0.0625}
# r2: 0.6552, std: 0.023 for {'C': 64, 'gamma': 0.03125}
# r2: 0.6579, std: 0.068 for {'C': 64, 'gamma': 0.015625}
# r2: 0.6330, std: 0.125 for {'C': 64, 'gamma': 0.0078125}
# r2: 0.6221, std: 0.135 for {'C': 64, 'gamma': 0.00390625}
# r2: 0.6212, std: 0.108 for {'C': 64, 'gamma': 0.001953125}
# r2: 0.6548, std: 0.069 for {'C': 64, 'gamma': 0.0009765625}
# r2: 0.3625, std: 0.059 for {'C': 128, 'gamma': 1.0}
# r2: 0.4452, std: 0.096 for {'C': 128, 'gamma': 0.5}
# r2: 0.5187, std: 0.091 for {'C': 128, 'gamma': 0.25}
# r2: 0.5645, std: 0.055 for {'C': 128, 'gamma': 0.125}
# r2: 0.5696, std: 0.103 for {'C': 128, 'gamma': 0.0625}
# r2: 0.6289, std: 0.037 for {'C': 128, 'gamma': 0.03125}
# r2: 0.6208, std: 0.075 for {'C': 128, 'gamma': 0.015625}
# r2: 0.6193, std: 0.127 for {'C': 128, 'gamma': 0.0078125}
# r2: 0.5885, std: 0.200 for {'C': 128, 'gamma': 0.00390625}
# r2: 0.6058, std: 0.139 for {'C': 128, 'gamma': 0.001953125}
# r2: 0.6378, std: 0.080 for {'C': 128, 'gamma': 0.0009765625}
# r2: 0.3450, std: 0.048 for {'C': 256, 'gamma': 1.0}
# r2: 0.4369, std: 0.104 for {'C': 256, 'gamma': 0.5}
# r2: 0.5034, std: 0.110 for {'C': 256, 'gamma': 0.25}
# r2: 0.5368, std: 0.058 for {'C': 256, 'gamma': 0.125}
# r2: 0.5314, std: 0.107 for {'C': 256, 'gamma': 0.0625}
# r2: 0.5797, std: 0.072 for {'C': 256, 'gamma': 0.03125}
# r2: 0.5743, std: 0.057 for {'C': 256, 'gamma': 0.015625}
# r2: 0.5914, std: 0.144 for {'C': 256, 'gamma': 0.0078125}
# r2: 0.5697, std: 0.218 for {'C': 256, 'gamma': 0.00390625}
# r2: 0.5764, std: 0.198 for {'C': 256, 'gamma': 0.001953125}
# r2: 0.5984, std: 0.131 for {'C': 256, 'gamma': 0.0009765625}
# r2: 0.3323, std: 0.050 for {'C': 512, 'gamma': 1.0}
# r2: 0.4403, std: 0.096 for {'C': 512, 'gamma': 0.5}
# r2: 0.4707, std: 0.115 for {'C': 512, 'gamma': 0.25}
# r2: 0.4866, std: 0.089 for {'C': 512, 'gamma': 0.125}
# r2: 0.4723, std: 0.102 for {'C': 512, 'gamma': 0.0625}
# r2: 0.5002, std: 0.104 for {'C': 512, 'gamma': 0.03125}
# r2: 0.5127, std: 0.060 for {'C': 512, 'gamma': 0.015625}
# r2: 0.5402, std: 0.160 for {'C': 512, 'gamma': 0.0078125}
# r2: 0.5693, std: 0.200 for {'C': 512, 'gamma': 0.00390625}
# r2: 0.5356, std: 0.286 for {'C': 512, 'gamma': 0.001953125}
# r2: 0.5773, std: 0.171 for {'C': 512, 'gamma': 0.0009765625}
# r2: 0.3053, std: 0.055 for {'C': 1024, 'gamma': 1.0}
# r2: 0.4388, std: 0.081 for {'C': 1024, 'gamma': 0.5}
# r2: 0.4490, std: 0.107 for {'C': 1024, 'gamma': 0.25}
# r2: 0.4218, std: 0.120 for {'C': 1024, 'gamma': 0.125}
# r2: 0.4184, std: 0.067 for {'C': 1024, 'gamma': 0.0625}
# r2: 0.3577, std: 0.168 for {'C': 1024, 'gamma': 0.03125}
# r2: 0.4682, std: 0.077 for {'C': 1024, 'gamma': 0.015625}
# r2: 0.4016, std: 0.215 for {'C': 1024, 'gamma': 0.0078125}
# r2: 0.5581, std: 0.183 for {'C': 1024, 'gamma': 0.00390625}
# r2: 0.5397, std: 0.278 for {'C': 1024, 'gamma': 0.001953125}
# r2: 0.5461, std: 0.232 for {'C': 1024, 'gamma': 0.0009765625}
# r2: 0.2521, std: 0.083 for {'C': 2048, 'gamma': 1.0}
# r2: 0.4166, std: 0.067 for {'C': 2048, 'gamma': 0.5}
# r2: 0.4007, std: 0.124 for {'C': 2048, 'gamma': 0.25}
# r2: 0.3202, std: 0.197 for {'C': 2048, 'gamma': 0.125}
# r2: 0.2249, std: 0.086 for {'C': 2048, 'gamma': 0.0625}
# r2: 0.2345, std: 0.168 for {'C': 2048, 'gamma': 0.03125}
# r2: 0.3377, std: 0.151 for {'C': 2048, 'gamma': 0.015625}
# r2: 0.1855, std: 0.352 for {'C': 2048, 'gamma': 0.0078125}
# r2: 0.5177, std: 0.190 for {'C': 2048, 'gamma': 0.00390625}
# r2: 0.5340, std: 0.256 for {'C': 2048, 'gamma': 0.001953125}
# r2: 0.4955, std: 0.334 for {'C': 2048, 'gamma': 0.0009765625}
# r2: 0.1680, std: 0.143 for {'C': 4096, 'gamma': 1.0}
# r2: 0.3709, std: 0.071 for {'C': 4096, 'gamma': 0.5}
# r2: 0.3446, std: 0.144 for {'C': 4096, 'gamma': 0.25}
# r2: 0.2234, std: 0.283 for {'C': 4096, 'gamma': 0.125}
# r2: -0.0799, std: 0.259 for {'C': 4096, 'gamma': 0.0625}
# r2: 0.0011, std: 0.210 for {'C': 4096, 'gamma': 0.03125}
# r2: 0.0889, std: 0.237 for {'C': 4096, 'gamma': 0.015625}
# r2: 0.0733, std: 0.482 for {'C': 4096, 'gamma': 0.0078125}
# r2: 0.4555, std: 0.189 for {'C': 4096, 'gamma': 0.00390625}
# r2: 0.5303, std: 0.225 for {'C': 4096, 'gamma': 0.001953125}
# r2: 0.4710, std: 0.396 for {'C': 4096, 'gamma': 0.0009765625}
# r2: -0.0503, std: 0.336 for {'C': 8192, 'gamma': 1.0}
# r2: 0.3174, std: 0.079 for {'C': 8192, 'gamma': 0.5}
# r2: 0.2812, std: 0.153 for {'C': 8192, 'gamma': 0.25}
# r2: 0.1683, std: 0.292 for {'C': 8192, 'gamma': 0.125}
# r2: -0.4105, std: 0.385 for {'C': 8192, 'gamma': 0.0625}
# r2: -0.5702, std: 0.905 for {'C': 8192, 'gamma': 0.03125}
# r2: -0.4791, std: 0.669 for {'C': 8192, 'gamma': 0.015625}
# r2: -0.0240, std: 0.524 for {'C': 8192, 'gamma': 0.0078125}
# r2: 0.3150, std: 0.199 for {'C': 8192, 'gamma': 0.00390625}
# r2: 0.4858, std: 0.253 for {'C': 8192, 'gamma': 0.001953125}
# r2: 0.4775, std: 0.371 for {'C': 8192, 'gamma': 0.0009765625}

# %%
y_pred = clf.predict(X_test)
r2_test = clf.score(X_test, y_test)
abs_test = abserr(y_pred, y_test)
print(r2_test, abs_test)
x0 = np.linspace(-2, 25, 100)
plt.plot(x0, x0, 'r')
plt.scatter(y_test, y_pred)

test_data['SVR'] = y_pred
# Out:
# 0.721263614805 1.9815035843

# %%
clf = SVR(C=4, gamma=0.03125)
clf.fit(X, y)
y_pred = clf.predict(X_test)
r2_test = clf.score(X_test, y_test)
abs_test = abserr(y_pred, y_test)
print(r2_test, abs_test)
x0 = np.linspace(-2, 25, 100)
plt.plot(x0, x0, 'r')
plt.scatter(y_test, y_pred)
test_data['SVR'] = y_pred
# Out:
# 0.864120197201 1.26434689745

# %%
######## DTR ######
clf = DecisionTreeRegressor()
######## Range ########
max_depth = np.linspace(2, 21, 20, dtype=int)
min_samples_split = np.linspace(2, 31, 30, dtype=int)
tuned_parameters = dict(max_depth=max_depth, min_samples_split=min_samples_split)
######## Param #########


clf = GridSearchCV(estimator=clf, param_grid=tuned_parameters, cv=cv, n_jobs=-1)
clf.fit(X_train, y_train)

print("The best parameters are %s with a score of %0.5f, test_score: %0.5f" % (clf.best_params_, clf.best_score_, clf.score(X_test, y_test)))
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("r2: %0.4f, std: %0.03f for %r" % (mean, std, params))
print()
# Out:
# The best parameters are {'max_depth': 7, 'min_samples_split': 12} with a score of 0.71005, test_score: 0.73653
#
# {'max_depth': 7, 'min_samples_split': 12}
#
# Grid scores on development set:
#
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 2}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 3}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 4}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 5}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 6}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 7}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 8}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 9}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 10}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 11}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 12}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 13}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 14}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 15}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 16}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 17}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 18}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 19}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 20}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 21}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 22}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 23}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 24}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 25}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 26}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 27}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 28}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 29}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 30}
# r2: 0.5289, std: 0.088 for {'max_depth': 2, 'min_samples_split': 31}
# r2: 0.6491, std: 0.045 for {'max_depth': 3, 'min_samples_split': 2}
# r2: 0.6491, std: 0.045 for {'max_depth': 3, 'min_samples_split': 3}
# r2: 0.6491, std: 0.045 for {'max_depth': 3, 'min_samples_split': 4}
# r2: 0.6505, std: 0.045 for {'max_depth': 3, 'min_samples_split': 5}
# r2: 0.6491, std: 0.045 for {'max_depth': 3, 'min_samples_split': 6}
# r2: 0.6491, std: 0.045 for {'max_depth': 3, 'min_samples_split': 7}
# r2: 0.6506, std: 0.045 for {'max_depth': 3, 'min_samples_split': 8}
# r2: 0.6506, std: 0.045 for {'max_depth': 3, 'min_samples_split': 9}
# r2: 0.6506, std: 0.045 for {'max_depth': 3, 'min_samples_split': 10}
# r2: 0.6506, std: 0.045 for {'max_depth': 3, 'min_samples_split': 11}
# r2: 0.6504, std: 0.045 for {'max_depth': 3, 'min_samples_split': 12}
# r2: 0.6503, std: 0.045 for {'max_depth': 3, 'min_samples_split': 13}
# r2: 0.6503, std: 0.045 for {'max_depth': 3, 'min_samples_split': 14}
# r2: 0.6503, std: 0.045 for {'max_depth': 3, 'min_samples_split': 15}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 16}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 17}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 18}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 19}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 20}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 21}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 22}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 23}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 24}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 25}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 26}
# r2: 0.6401, std: 0.051 for {'max_depth': 3, 'min_samples_split': 27}
# r2: 0.6422, std: 0.053 for {'max_depth': 3, 'min_samples_split': 28}
# r2: 0.6422, std: 0.053 for {'max_depth': 3, 'min_samples_split': 29}
# r2: 0.6422, std: 0.053 for {'max_depth': 3, 'min_samples_split': 30}
# r2: 0.6422, std: 0.053 for {'max_depth': 3, 'min_samples_split': 31}
# r2: 0.6877, std: 0.035 for {'max_depth': 4, 'min_samples_split': 2}
# r2: 0.6880, std: 0.036 for {'max_depth': 4, 'min_samples_split': 3}
# r2: 0.6857, std: 0.034 for {'max_depth': 4, 'min_samples_split': 4}
# r2: 0.6859, std: 0.034 for {'max_depth': 4, 'min_samples_split': 5}
# r2: 0.6856, std: 0.034 for {'max_depth': 4, 'min_samples_split': 6}
# r2: 0.6869, std: 0.034 for {'max_depth': 4, 'min_samples_split': 7}
# r2: 0.6916, std: 0.033 for {'max_depth': 4, 'min_samples_split': 8}
# r2: 0.6917, std: 0.033 for {'max_depth': 4, 'min_samples_split': 9}
# r2: 0.6907, std: 0.033 for {'max_depth': 4, 'min_samples_split': 10}
# r2: 0.6907, std: 0.033 for {'max_depth': 4, 'min_samples_split': 11}
# r2: 0.7028, std: 0.045 for {'max_depth': 4, 'min_samples_split': 12}
# r2: 0.7026, std: 0.046 for {'max_depth': 4, 'min_samples_split': 13}
# r2: 0.7019, std: 0.045 for {'max_depth': 4, 'min_samples_split': 14}
# r2: 0.7019, std: 0.045 for {'max_depth': 4, 'min_samples_split': 15}
# r2: 0.6917, std: 0.053 for {'max_depth': 4, 'min_samples_split': 16}
# r2: 0.6917, std: 0.053 for {'max_depth': 4, 'min_samples_split': 17}
# r2: 0.6917, std: 0.053 for {'max_depth': 4, 'min_samples_split': 18}
# r2: 0.6917, std: 0.053 for {'max_depth': 4, 'min_samples_split': 19}
# r2: 0.6913, std: 0.053 for {'max_depth': 4, 'min_samples_split': 20}
# r2: 0.6913, std: 0.053 for {'max_depth': 4, 'min_samples_split': 21}
# r2: 0.6918, std: 0.052 for {'max_depth': 4, 'min_samples_split': 22}
# r2: 0.6873, std: 0.051 for {'max_depth': 4, 'min_samples_split': 23}
# r2: 0.6873, std: 0.051 for {'max_depth': 4, 'min_samples_split': 24}
# r2: 0.6873, std: 0.051 for {'max_depth': 4, 'min_samples_split': 25}
# r2: 0.6873, std: 0.051 for {'max_depth': 4, 'min_samples_split': 26}
# r2: 0.6873, std: 0.051 for {'max_depth': 4, 'min_samples_split': 27}
# r2: 0.6894, std: 0.052 for {'max_depth': 4, 'min_samples_split': 28}
# r2: 0.6890, std: 0.051 for {'max_depth': 4, 'min_samples_split': 29}
# r2: 0.6885, std: 0.052 for {'max_depth': 4, 'min_samples_split': 30}
# r2: 0.6885, std: 0.052 for {'max_depth': 4, 'min_samples_split': 31}
# r2: 0.6884, std: 0.021 for {'max_depth': 5, 'min_samples_split': 2}
# r2: 0.6933, std: 0.020 for {'max_depth': 5, 'min_samples_split': 3}
# r2: 0.6888, std: 0.020 for {'max_depth': 5, 'min_samples_split': 4}
# r2: 0.6894, std: 0.020 for {'max_depth': 5, 'min_samples_split': 5}
# r2: 0.6800, std: 0.016 for {'max_depth': 5, 'min_samples_split': 6}
# r2: 0.6859, std: 0.016 for {'max_depth': 5, 'min_samples_split': 7}
# r2: 0.6863, std: 0.015 for {'max_depth': 5, 'min_samples_split': 8}
# r2: 0.6896, std: 0.014 for {'max_depth': 5, 'min_samples_split': 9}
# r2: 0.6880, std: 0.015 for {'max_depth': 5, 'min_samples_split': 10}
# r2: 0.6854, std: 0.014 for {'max_depth': 5, 'min_samples_split': 11}
# r2: 0.7013, std: 0.028 for {'max_depth': 5, 'min_samples_split': 12}
# r2: 0.7011, std: 0.028 for {'max_depth': 5, 'min_samples_split': 13}
# r2: 0.7005, std: 0.028 for {'max_depth': 5, 'min_samples_split': 14}
# r2: 0.7018, std: 0.028 for {'max_depth': 5, 'min_samples_split': 15}
# r2: 0.6917, std: 0.038 for {'max_depth': 5, 'min_samples_split': 16}
# r2: 0.6873, std: 0.038 for {'max_depth': 5, 'min_samples_split': 17}
# r2: 0.6873, std: 0.038 for {'max_depth': 5, 'min_samples_split': 18}
# r2: 0.6876, std: 0.039 for {'max_depth': 5, 'min_samples_split': 19}
# r2: 0.6852, std: 0.040 for {'max_depth': 5, 'min_samples_split': 20}
# r2: 0.6848, std: 0.039 for {'max_depth': 5, 'min_samples_split': 21}
# r2: 0.6849, std: 0.039 for {'max_depth': 5, 'min_samples_split': 22}
# r2: 0.6804, std: 0.039 for {'max_depth': 5, 'min_samples_split': 23}
# r2: 0.6802, std: 0.039 for {'max_depth': 5, 'min_samples_split': 24}
# r2: 0.6802, std: 0.039 for {'max_depth': 5, 'min_samples_split': 25}
# r2: 0.6802, std: 0.039 for {'max_depth': 5, 'min_samples_split': 26}
# r2: 0.6802, std: 0.039 for {'max_depth': 5, 'min_samples_split': 27}
# r2: 0.6821, std: 0.039 for {'max_depth': 5, 'min_samples_split': 28}
# r2: 0.6816, std: 0.038 for {'max_depth': 5, 'min_samples_split': 29}
# r2: 0.6811, std: 0.039 for {'max_depth': 5, 'min_samples_split': 30}
# r2: 0.6811, std: 0.039 for {'max_depth': 5, 'min_samples_split': 31}
# r2: 0.6811, std: 0.014 for {'max_depth': 6, 'min_samples_split': 2}
# r2: 0.6805, std: 0.012 for {'max_depth': 6, 'min_samples_split': 3}
# r2: 0.6847, std: 0.021 for {'max_depth': 6, 'min_samples_split': 4}
# r2: 0.6839, std: 0.013 for {'max_depth': 6, 'min_samples_split': 5}
# r2: 0.6783, std: 0.018 for {'max_depth': 6, 'min_samples_split': 6}
# r2: 0.6812, std: 0.017 for {'max_depth': 6, 'min_samples_split': 7}
# r2: 0.6786, std: 0.009 for {'max_depth': 6, 'min_samples_split': 8}
# r2: 0.6856, std: 0.014 for {'max_depth': 6, 'min_samples_split': 9}
# r2: 0.6772, std: 0.011 for {'max_depth': 6, 'min_samples_split': 10}
# r2: 0.6807, std: 0.015 for {'max_depth': 6, 'min_samples_split': 11}
# r2: 0.6952, std: 0.028 for {'max_depth': 6, 'min_samples_split': 12}
# r2: 0.6931, std: 0.022 for {'max_depth': 6, 'min_samples_split': 13}
# r2: 0.6941, std: 0.028 for {'max_depth': 6, 'min_samples_split': 14}
# r2: 0.6917, std: 0.022 for {'max_depth': 6, 'min_samples_split': 15}
# r2: 0.6836, std: 0.032 for {'max_depth': 6, 'min_samples_split': 16}
# r2: 0.6823, std: 0.040 for {'max_depth': 6, 'min_samples_split': 17}
# r2: 0.6807, std: 0.040 for {'max_depth': 6, 'min_samples_split': 18}
# r2: 0.6775, std: 0.035 for {'max_depth': 6, 'min_samples_split': 19}
# r2: 0.6786, std: 0.040 for {'max_depth': 6, 'min_samples_split': 20}
# r2: 0.6748, std: 0.035 for {'max_depth': 6, 'min_samples_split': 21}
# r2: 0.6784, std: 0.040 for {'max_depth': 6, 'min_samples_split': 22}
# r2: 0.6723, std: 0.031 for {'max_depth': 6, 'min_samples_split': 23}
# r2: 0.6702, std: 0.032 for {'max_depth': 6, 'min_samples_split': 24}
# r2: 0.6699, std: 0.031 for {'max_depth': 6, 'min_samples_split': 25}
# r2: 0.6734, std: 0.037 for {'max_depth': 6, 'min_samples_split': 26}
# r2: 0.6718, std: 0.031 for {'max_depth': 6, 'min_samples_split': 27}
# r2: 0.6767, std: 0.038 for {'max_depth': 6, 'min_samples_split': 28}
# r2: 0.6761, std: 0.037 for {'max_depth': 6, 'min_samples_split': 29}
# r2: 0.6734, std: 0.032 for {'max_depth': 6, 'min_samples_split': 30}
# r2: 0.6768, std: 0.038 for {'max_depth': 6, 'min_samples_split': 31}
# r2: 0.6890, std: 0.025 for {'max_depth': 7, 'min_samples_split': 2}
# r2: 0.6678, std: 0.054 for {'max_depth': 7, 'min_samples_split': 3}
# r2: 0.6971, std: 0.030 for {'max_depth': 7, 'min_samples_split': 4}
# r2: 0.6934, std: 0.025 for {'max_depth': 7, 'min_samples_split': 5}
# r2: 0.6800, std: 0.062 for {'max_depth': 7, 'min_samples_split': 6}
# r2: 0.6917, std: 0.024 for {'max_depth': 7, 'min_samples_split': 7}
# r2: 0.6963, std: 0.025 for {'max_depth': 7, 'min_samples_split': 8}
# r2: 0.6947, std: 0.027 for {'max_depth': 7, 'min_samples_split': 9}
# r2: 0.6852, std: 0.026 for {'max_depth': 7, 'min_samples_split': 10}
# r2: 0.6932, std: 0.029 for {'max_depth': 7, 'min_samples_split': 11}
# r2: 0.7100, std: 0.031 for {'max_depth': 7, 'min_samples_split': 12}
# r2: 0.7026, std: 0.032 for {'max_depth': 7, 'min_samples_split': 13}
# r2: 0.7030, std: 0.027 for {'max_depth': 7, 'min_samples_split': 14}
# r2: 0.7078, std: 0.034 for {'max_depth': 7, 'min_samples_split': 15}
# r2: 0.6975, std: 0.044 for {'max_depth': 7, 'min_samples_split': 16}
# r2: 0.6940, std: 0.040 for {'max_depth': 7, 'min_samples_split': 17}
# r2: 0.6940, std: 0.042 for {'max_depth': 7, 'min_samples_split': 18}
# r2: 0.6914, std: 0.035 for {'max_depth': 7, 'min_samples_split': 19}
# r2: 0.6890, std: 0.035 for {'max_depth': 7, 'min_samples_split': 20}
# r2: 0.6887, std: 0.035 for {'max_depth': 7, 'min_samples_split': 21}
# r2: 0.6885, std: 0.035 for {'max_depth': 7, 'min_samples_split': 22}
# r2: 0.6669, std: 0.051 for {'max_depth': 7, 'min_samples_split': 23}
# r2: 0.6667, std: 0.051 for {'max_depth': 7, 'min_samples_split': 24}
# r2: 0.6792, std: 0.031 for {'max_depth': 7, 'min_samples_split': 25}
# r2: 0.6821, std: 0.040 for {'max_depth': 7, 'min_samples_split': 26}
# r2: 0.6821, std: 0.040 for {'max_depth': 7, 'min_samples_split': 27}
# r2: 0.6682, std: 0.057 for {'max_depth': 7, 'min_samples_split': 28}
# r2: 0.6798, std: 0.031 for {'max_depth': 7, 'min_samples_split': 29}
# r2: 0.6851, std: 0.039 for {'max_depth': 7, 'min_samples_split': 30}
# r2: 0.6805, std: 0.031 for {'max_depth': 7, 'min_samples_split': 31}
# r2: 0.6792, std: 0.037 for {'max_depth': 8, 'min_samples_split': 2}
# r2: 0.6841, std: 0.033 for {'max_depth': 8, 'min_samples_split': 3}
# r2: 0.6757, std: 0.070 for {'max_depth': 8, 'min_samples_split': 4}
# r2: 0.6878, std: 0.037 for {'max_depth': 8, 'min_samples_split': 5}
# r2: 0.6727, std: 0.039 for {'max_depth': 8, 'min_samples_split': 6}
# r2: 0.6802, std: 0.046 for {'max_depth': 8, 'min_samples_split': 7}
# r2: 0.6891, std: 0.044 for {'max_depth': 8, 'min_samples_split': 8}
# r2: 0.6862, std: 0.042 for {'max_depth': 8, 'min_samples_split': 9}
# r2: 0.6819, std: 0.041 for {'max_depth': 8, 'min_samples_split': 10}
# r2: 0.6808, std: 0.048 for {'max_depth': 8, 'min_samples_split': 11}
# r2: 0.6735, std: 0.077 for {'max_depth': 8, 'min_samples_split': 12}
# r2: 0.6946, std: 0.049 for {'max_depth': 8, 'min_samples_split': 13}
# r2: 0.6966, std: 0.047 for {'max_depth': 8, 'min_samples_split': 14}
# r2: 0.6937, std: 0.040 for {'max_depth': 8, 'min_samples_split': 15}
# r2: 0.6669, std: 0.072 for {'max_depth': 8, 'min_samples_split': 16}
# r2: 0.6857, std: 0.038 for {'max_depth': 8, 'min_samples_split': 17}
# r2: 0.6885, std: 0.034 for {'max_depth': 8, 'min_samples_split': 18}
# r2: 0.6934, std: 0.041 for {'max_depth': 8, 'min_samples_split': 19}
# r2: 0.6899, std: 0.042 for {'max_depth': 8, 'min_samples_split': 20}
# r2: 0.6861, std: 0.034 for {'max_depth': 8, 'min_samples_split': 21}
# r2: 0.6668, std: 0.054 for {'max_depth': 8, 'min_samples_split': 22}
# r2: 0.6802, std: 0.031 for {'max_depth': 8, 'min_samples_split': 23}
# r2: 0.6813, std: 0.036 for {'max_depth': 8, 'min_samples_split': 24}
# r2: 0.6609, std: 0.051 for {'max_depth': 8, 'min_samples_split': 25}
# r2: 0.6779, std: 0.034 for {'max_depth': 8, 'min_samples_split': 26}
# r2: 0.6769, std: 0.033 for {'max_depth': 8, 'min_samples_split': 27}
# r2: 0.6760, std: 0.034 for {'max_depth': 8, 'min_samples_split': 28}
# r2: 0.6798, std: 0.040 for {'max_depth': 8, 'min_samples_split': 29}
# r2: 0.6588, std: 0.048 for {'max_depth': 8, 'min_samples_split': 30}
# r2: 0.6588, std: 0.048 for {'max_depth': 8, 'min_samples_split': 31}
# r2: 0.6739, std: 0.057 for {'max_depth': 9, 'min_samples_split': 2}
# r2: 0.6718, std: 0.074 for {'max_depth': 9, 'min_samples_split': 3}
# r2: 0.6987, std: 0.053 for {'max_depth': 9, 'min_samples_split': 4}
# r2: 0.6893, std: 0.041 for {'max_depth': 9, 'min_samples_split': 5}
# r2: 0.6839, std: 0.050 for {'max_depth': 9, 'min_samples_split': 6}
# r2: 0.6877, std: 0.048 for {'max_depth': 9, 'min_samples_split': 7}
# r2: 0.6915, std: 0.038 for {'max_depth': 9, 'min_samples_split': 8}
# r2: 0.6925, std: 0.040 for {'max_depth': 9, 'min_samples_split': 9}
# r2: 0.6922, std: 0.042 for {'max_depth': 9, 'min_samples_split': 10}
# r2: 0.6917, std: 0.047 for {'max_depth': 9, 'min_samples_split': 11}
# r2: 0.7056, std: 0.045 for {'max_depth': 9, 'min_samples_split': 12}
# r2: 0.6809, std: 0.078 for {'max_depth': 9, 'min_samples_split': 13}
# r2: 0.6844, std: 0.080 for {'max_depth': 9, 'min_samples_split': 14}
# r2: 0.7092, std: 0.044 for {'max_depth': 9, 'min_samples_split': 15}
# r2: 0.6955, std: 0.049 for {'max_depth': 9, 'min_samples_split': 16}
# r2: 0.6940, std: 0.032 for {'max_depth': 9, 'min_samples_split': 17}
# r2: 0.6881, std: 0.053 for {'max_depth': 9, 'min_samples_split': 18}
# r2: 0.6981, std: 0.025 for {'max_depth': 9, 'min_samples_split': 19}
# r2: 0.6860, std: 0.057 for {'max_depth': 9, 'min_samples_split': 20}
# r2: 0.6982, std: 0.023 for {'max_depth': 9, 'min_samples_split': 21}
# r2: 0.6953, std: 0.024 for {'max_depth': 9, 'min_samples_split': 22}
# r2: 0.6889, std: 0.025 for {'max_depth': 9, 'min_samples_split': 23}
# r2: 0.6753, std: 0.049 for {'max_depth': 9, 'min_samples_split': 24}
# r2: 0.6925, std: 0.036 for {'max_depth': 9, 'min_samples_split': 25}
# r2: 0.6754, std: 0.055 for {'max_depth': 9, 'min_samples_split': 26}
# r2: 0.6880, std: 0.035 for {'max_depth': 9, 'min_samples_split': 27}
# r2: 0.6786, std: 0.022 for {'max_depth': 9, 'min_samples_split': 28}
# r2: 0.6850, std: 0.028 for {'max_depth': 9, 'min_samples_split': 29}
# r2: 0.6811, std: 0.021 for {'max_depth': 9, 'min_samples_split': 30}
# r2: 0.6811, std: 0.021 for {'max_depth': 9, 'min_samples_split': 31}
# r2: 0.6627, std: 0.054 for {'max_depth': 10, 'min_samples_split': 2}
# r2: 0.6616, std: 0.045 for {'max_depth': 10, 'min_samples_split': 3}
# r2: 0.6772, std: 0.046 for {'max_depth': 10, 'min_samples_split': 4}
# r2: 0.6532, std: 0.066 for {'max_depth': 10, 'min_samples_split': 5}
# r2: 0.6590, std: 0.039 for {'max_depth': 10, 'min_samples_split': 6}
# r2: 0.6579, std: 0.043 for {'max_depth': 10, 'min_samples_split': 7}
# r2: 0.6636, std: 0.039 for {'max_depth': 10, 'min_samples_split': 8}
# r2: 0.6453, std: 0.064 for {'max_depth': 10, 'min_samples_split': 9}
# r2: 0.6494, std: 0.070 for {'max_depth': 10, 'min_samples_split': 10}
# r2: 0.6614, std: 0.050 for {'max_depth': 10, 'min_samples_split': 11}
# r2: 0.6783, std: 0.048 for {'max_depth': 10, 'min_samples_split': 12}
# r2: 0.6738, std: 0.057 for {'max_depth': 10, 'min_samples_split': 13}
# r2: 0.6693, std: 0.050 for {'max_depth': 10, 'min_samples_split': 14}
# r2: 0.6603, std: 0.075 for {'max_depth': 10, 'min_samples_split': 15}
# r2: 0.6637, std: 0.065 for {'max_depth': 10, 'min_samples_split': 16}
# r2: 0.6716, std: 0.055 for {'max_depth': 10, 'min_samples_split': 17}
# r2: 0.6801, std: 0.054 for {'max_depth': 10, 'min_samples_split': 18}
# r2: 0.6823, std: 0.060 for {'max_depth': 10, 'min_samples_split': 19}
# r2: 0.6780, std: 0.053 for {'max_depth': 10, 'min_samples_split': 20}
# r2: 0.6858, std: 0.039 for {'max_depth': 10, 'min_samples_split': 21}
# r2: 0.6829, std: 0.038 for {'max_depth': 10, 'min_samples_split': 22}
# r2: 0.6792, std: 0.035 for {'max_depth': 10, 'min_samples_split': 23}
# r2: 0.6846, std: 0.048 for {'max_depth': 10, 'min_samples_split': 24}
# r2: 0.6588, std: 0.057 for {'max_depth': 10, 'min_samples_split': 25}
# r2: 0.6588, std: 0.057 for {'max_depth': 10, 'min_samples_split': 26}
# r2: 0.6570, std: 0.055 for {'max_depth': 10, 'min_samples_split': 27}
# r2: 0.6689, std: 0.036 for {'max_depth': 10, 'min_samples_split': 28}
# r2: 0.6707, std: 0.035 for {'max_depth': 10, 'min_samples_split': 29}
# r2: 0.6703, std: 0.033 for {'max_depth': 10, 'min_samples_split': 30}
# r2: 0.6733, std: 0.034 for {'max_depth': 10, 'min_samples_split': 31}
# r2: 0.6551, std: 0.062 for {'max_depth': 11, 'min_samples_split': 2}
# r2: 0.6656, std: 0.053 for {'max_depth': 11, 'min_samples_split': 3}
# r2: 0.6642, std: 0.057 for {'max_depth': 11, 'min_samples_split': 4}
# r2: 0.6651, std: 0.056 for {'max_depth': 11, 'min_samples_split': 5}
# r2: 0.6506, std: 0.046 for {'max_depth': 11, 'min_samples_split': 6}
# r2: 0.6520, std: 0.041 for {'max_depth': 11, 'min_samples_split': 7}
# r2: 0.6615, std: 0.064 for {'max_depth': 11, 'min_samples_split': 8}
# r2: 0.6440, std: 0.078 for {'max_depth': 11, 'min_samples_split': 9}
# r2: 0.6648, std: 0.051 for {'max_depth': 11, 'min_samples_split': 10}
# r2: 0.6576, std: 0.049 for {'max_depth': 11, 'min_samples_split': 11}
# r2: 0.6604, std: 0.086 for {'max_depth': 11, 'min_samples_split': 12}
# r2: 0.6726, std: 0.066 for {'max_depth': 11, 'min_samples_split': 13}
# r2: 0.6546, std: 0.084 for {'max_depth': 11, 'min_samples_split': 14}
# r2: 0.6841, std: 0.057 for {'max_depth': 11, 'min_samples_split': 15}
# r2: 0.6752, std: 0.065 for {'max_depth': 11, 'min_samples_split': 16}
# r2: 0.6791, std: 0.058 for {'max_depth': 11, 'min_samples_split': 17}
# r2: 0.6836, std: 0.056 for {'max_depth': 11, 'min_samples_split': 18}
# r2: 0.6805, std: 0.056 for {'max_depth': 11, 'min_samples_split': 19}
# r2: 0.6782, std: 0.056 for {'max_depth': 11, 'min_samples_split': 20}
# r2: 0.6870, std: 0.038 for {'max_depth': 11, 'min_samples_split': 21}
# r2: 0.6861, std: 0.046 for {'max_depth': 11, 'min_samples_split': 22}
# r2: 0.6823, std: 0.043 for {'max_depth': 11, 'min_samples_split': 23}
# r2: 0.6687, std: 0.064 for {'max_depth': 11, 'min_samples_split': 24}
# r2: 0.6770, std: 0.041 for {'max_depth': 11, 'min_samples_split': 25}
# r2: 0.6790, std: 0.049 for {'max_depth': 11, 'min_samples_split': 26}
# r2: 0.6753, std: 0.039 for {'max_depth': 11, 'min_samples_split': 27}
# r2: 0.6774, std: 0.041 for {'max_depth': 11, 'min_samples_split': 28}
# r2: 0.6719, std: 0.035 for {'max_depth': 11, 'min_samples_split': 29}
# r2: 0.6762, std: 0.039 for {'max_depth': 11, 'min_samples_split': 30}
# r2: 0.6574, std: 0.044 for {'max_depth': 11, 'min_samples_split': 31}
# r2: 0.6287, std: 0.082 for {'max_depth': 12, 'min_samples_split': 2}
# r2: 0.6501, std: 0.072 for {'max_depth': 12, 'min_samples_split': 3}
# r2: 0.6483, std: 0.059 for {'max_depth': 12, 'min_samples_split': 4}
# r2: 0.6566, std: 0.077 for {'max_depth': 12, 'min_samples_split': 5}
# r2: 0.6256, std: 0.087 for {'max_depth': 12, 'min_samples_split': 6}
# r2: 0.6246, std: 0.082 for {'max_depth': 12, 'min_samples_split': 7}
# r2: 0.6361, std: 0.084 for {'max_depth': 12, 'min_samples_split': 8}
# r2: 0.6600, std: 0.049 for {'max_depth': 12, 'min_samples_split': 9}
# r2: 0.6605, std: 0.050 for {'max_depth': 12, 'min_samples_split': 10}
# r2: 0.6602, std: 0.048 for {'max_depth': 12, 'min_samples_split': 11}
# r2: 0.6757, std: 0.055 for {'max_depth': 12, 'min_samples_split': 12}
# r2: 0.6734, std: 0.059 for {'max_depth': 12, 'min_samples_split': 13}
# r2: 0.6738, std: 0.058 for {'max_depth': 12, 'min_samples_split': 14}
# r2: 0.6791, std: 0.047 for {'max_depth': 12, 'min_samples_split': 15}
# r2: 0.6719, std: 0.065 for {'max_depth': 12, 'min_samples_split': 16}
# r2: 0.6681, std: 0.054 for {'max_depth': 12, 'min_samples_split': 17}
# r2: 0.6776, std: 0.056 for {'max_depth': 12, 'min_samples_split': 18}
# r2: 0.6796, std: 0.055 for {'max_depth': 12, 'min_samples_split': 19}
# r2: 0.6819, std: 0.060 for {'max_depth': 12, 'min_samples_split': 20}
# r2: 0.6880, std: 0.045 for {'max_depth': 12, 'min_samples_split': 21}
# r2: 0.6777, std: 0.040 for {'max_depth': 12, 'min_samples_split': 22}
# r2: 0.6740, std: 0.036 for {'max_depth': 12, 'min_samples_split': 23}
# r2: 0.6821, std: 0.048 for {'max_depth': 12, 'min_samples_split': 24}
# r2: 0.6780, std: 0.049 for {'max_depth': 12, 'min_samples_split': 25}
# r2: 0.6707, std: 0.043 for {'max_depth': 12, 'min_samples_split': 26}
# r2: 0.6763, std: 0.047 for {'max_depth': 12, 'min_samples_split': 27}
# r2: 0.6711, std: 0.043 for {'max_depth': 12, 'min_samples_split': 28}
# r2: 0.6655, std: 0.036 for {'max_depth': 12, 'min_samples_split': 29}
# r2: 0.6580, std: 0.050 for {'max_depth': 12, 'min_samples_split': 30}
# r2: 0.6708, std: 0.036 for {'max_depth': 12, 'min_samples_split': 31}
# r2: 0.6012, std: 0.085 for {'max_depth': 13, 'min_samples_split': 2}
# r2: 0.6428, std: 0.074 for {'max_depth': 13, 'min_samples_split': 3}
# r2: 0.6213, std: 0.091 for {'max_depth': 13, 'min_samples_split': 4}
# r2: 0.6529, std: 0.065 for {'max_depth': 13, 'min_samples_split': 5}
# r2: 0.6419, std: 0.055 for {'max_depth': 13, 'min_samples_split': 6}
# r2: 0.6298, std: 0.061 for {'max_depth': 13, 'min_samples_split': 7}
# r2: 0.6375, std: 0.087 for {'max_depth': 13, 'min_samples_split': 8}
# r2: 0.6593, std: 0.050 for {'max_depth': 13, 'min_samples_split': 9}
# r2: 0.6603, std: 0.051 for {'max_depth': 13, 'min_samples_split': 10}
# r2: 0.6430, std: 0.078 for {'max_depth': 13, 'min_samples_split': 11}
# r2: 0.6523, std: 0.083 for {'max_depth': 13, 'min_samples_split': 12}
# r2: 0.6647, std: 0.060 for {'max_depth': 13, 'min_samples_split': 13}
# r2: 0.6562, std: 0.087 for {'max_depth': 13, 'min_samples_split': 14}
# r2: 0.6742, std: 0.054 for {'max_depth': 13, 'min_samples_split': 15}
# r2: 0.6666, std: 0.062 for {'max_depth': 13, 'min_samples_split': 16}
# r2: 0.6711, std: 0.054 for {'max_depth': 13, 'min_samples_split': 17}
# r2: 0.6773, std: 0.057 for {'max_depth': 13, 'min_samples_split': 18}
# r2: 0.6843, std: 0.062 for {'max_depth': 13, 'min_samples_split': 19}
# r2: 0.6648, std: 0.075 for {'max_depth': 13, 'min_samples_split': 20}
# r2: 0.6880, std: 0.046 for {'max_depth': 13, 'min_samples_split': 21}
# r2: 0.6850, std: 0.046 for {'max_depth': 13, 'min_samples_split': 22}
# r2: 0.6787, std: 0.045 for {'max_depth': 13, 'min_samples_split': 23}
# r2: 0.6794, std: 0.051 for {'max_depth': 13, 'min_samples_split': 24}
# r2: 0.6609, std: 0.064 for {'max_depth': 13, 'min_samples_split': 25}
# r2: 0.6707, std: 0.044 for {'max_depth': 13, 'min_samples_split': 26}
# r2: 0.6715, std: 0.041 for {'max_depth': 13, 'min_samples_split': 27}
# r2: 0.6710, std: 0.044 for {'max_depth': 13, 'min_samples_split': 28}
# r2: 0.6729, std: 0.044 for {'max_depth': 13, 'min_samples_split': 29}
# r2: 0.6539, std: 0.045 for {'max_depth': 13, 'min_samples_split': 30}
# r2: 0.6543, std: 0.045 for {'max_depth': 13, 'min_samples_split': 31}
# r2: 0.6237, std: 0.082 for {'max_depth': 14, 'min_samples_split': 2}
# r2: 0.6452, std: 0.065 for {'max_depth': 14, 'min_samples_split': 3}
# r2: 0.6350, std: 0.072 for {'max_depth': 14, 'min_samples_split': 4}
# r2: 0.6357, std: 0.093 for {'max_depth': 14, 'min_samples_split': 5}
# r2: 0.6399, std: 0.062 for {'max_depth': 14, 'min_samples_split': 6}
# r2: 0.6433, std: 0.055 for {'max_depth': 14, 'min_samples_split': 7}
# r2: 0.6308, std: 0.079 for {'max_depth': 14, 'min_samples_split': 8}
# r2: 0.6412, std: 0.079 for {'max_depth': 14, 'min_samples_split': 9}
# r2: 0.6629, std: 0.059 for {'max_depth': 14, 'min_samples_split': 10}
# r2: 0.6536, std: 0.050 for {'max_depth': 14, 'min_samples_split': 11}
# r2: 0.6743, std: 0.061 for {'max_depth': 14, 'min_samples_split': 12}
# r2: 0.6667, std: 0.059 for {'max_depth': 14, 'min_samples_split': 13}
# r2: 0.6661, std: 0.060 for {'max_depth': 14, 'min_samples_split': 14}
# r2: 0.6800, std: 0.049 for {'max_depth': 14, 'min_samples_split': 15}
# r2: 0.6667, std: 0.065 for {'max_depth': 14, 'min_samples_split': 16}
# r2: 0.6672, std: 0.055 for {'max_depth': 14, 'min_samples_split': 17}
# r2: 0.6799, std: 0.057 for {'max_depth': 14, 'min_samples_split': 18}
# r2: 0.6803, std: 0.057 for {'max_depth': 14, 'min_samples_split': 19}
# r2: 0.6609, std: 0.070 for {'max_depth': 14, 'min_samples_split': 20}
# r2: 0.6841, std: 0.040 for {'max_depth': 14, 'min_samples_split': 21}
# r2: 0.6831, std: 0.048 for {'max_depth': 14, 'min_samples_split': 22}
# r2: 0.6604, std: 0.053 for {'max_depth': 14, 'min_samples_split': 23}
# r2: 0.6782, std: 0.044 for {'max_depth': 14, 'min_samples_split': 24}
# r2: 0.6714, std: 0.044 for {'max_depth': 14, 'min_samples_split': 25}
# r2: 0.6780, std: 0.050 for {'max_depth': 14, 'min_samples_split': 26}
# r2: 0.6762, std: 0.048 for {'max_depth': 14, 'min_samples_split': 27}
# r2: 0.6567, std: 0.055 for {'max_depth': 14, 'min_samples_split': 28}
# r2: 0.6558, std: 0.054 for {'max_depth': 14, 'min_samples_split': 29}
# r2: 0.6710, std: 0.036 for {'max_depth': 14, 'min_samples_split': 30}
# r2: 0.6760, std: 0.042 for {'max_depth': 14, 'min_samples_split': 31}
# r2: 0.6065, std: 0.094 for {'max_depth': 15, 'min_samples_split': 2}
# r2: 0.6194, std: 0.103 for {'max_depth': 15, 'min_samples_split': 3}
# r2: 0.6345, std: 0.076 for {'max_depth': 15, 'min_samples_split': 4}
# r2: 0.6495, std: 0.075 for {'max_depth': 15, 'min_samples_split': 5}
# r2: 0.6369, std: 0.058 for {'max_depth': 15, 'min_samples_split': 6}
# r2: 0.6386, std: 0.056 for {'max_depth': 15, 'min_samples_split': 7}
# r2: 0.6428, std: 0.054 for {'max_depth': 15, 'min_samples_split': 8}
# r2: 0.6570, std: 0.054 for {'max_depth': 15, 'min_samples_split': 9}
# r2: 0.6351, std: 0.077 for {'max_depth': 15, 'min_samples_split': 10}
# r2: 0.6384, std: 0.079 for {'max_depth': 15, 'min_samples_split': 11}
# r2: 0.6673, std: 0.054 for {'max_depth': 15, 'min_samples_split': 12}
# r2: 0.6702, std: 0.061 for {'max_depth': 15, 'min_samples_split': 13}
# r2: 0.6736, std: 0.059 for {'max_depth': 15, 'min_samples_split': 14}
# r2: 0.6770, std: 0.052 for {'max_depth': 15, 'min_samples_split': 15}
# r2: 0.6648, std: 0.066 for {'max_depth': 15, 'min_samples_split': 16}
# r2: 0.6687, std: 0.054 for {'max_depth': 15, 'min_samples_split': 17}
# r2: 0.6798, std: 0.057 for {'max_depth': 15, 'min_samples_split': 18}
# r2: 0.6850, std: 0.062 for {'max_depth': 15, 'min_samples_split': 19}
# r2: 0.6609, std: 0.070 for {'max_depth': 15, 'min_samples_split': 20}
# r2: 0.6841, std: 0.040 for {'max_depth': 15, 'min_samples_split': 21}
# r2: 0.6811, std: 0.040 for {'max_depth': 15, 'min_samples_split': 22}
# r2: 0.6794, std: 0.045 for {'max_depth': 15, 'min_samples_split': 23}
# r2: 0.6829, std: 0.050 for {'max_depth': 15, 'min_samples_split': 24}
# r2: 0.6761, std: 0.052 for {'max_depth': 15, 'min_samples_split': 25}
# r2: 0.6706, std: 0.044 for {'max_depth': 15, 'min_samples_split': 26}
# r2: 0.6762, std: 0.048 for {'max_depth': 15, 'min_samples_split': 27}
# r2: 0.6664, std: 0.038 for {'max_depth': 15, 'min_samples_split': 28}
# r2: 0.6558, std: 0.054 for {'max_depth': 15, 'min_samples_split': 29}
# r2: 0.6585, std: 0.051 for {'max_depth': 15, 'min_samples_split': 30}
# r2: 0.6760, std: 0.042 for {'max_depth': 15, 'min_samples_split': 31}
# r2: 0.6025, std: 0.102 for {'max_depth': 16, 'min_samples_split': 2}
# r2: 0.6192, std: 0.070 for {'max_depth': 16, 'min_samples_split': 3}
# r2: 0.6440, std: 0.058 for {'max_depth': 16, 'min_samples_split': 4}
# r2: 0.6346, std: 0.100 for {'max_depth': 16, 'min_samples_split': 5}
# r2: 0.6326, std: 0.055 for {'max_depth': 16, 'min_samples_split': 6}
# r2: 0.6398, std: 0.057 for {'max_depth': 16, 'min_samples_split': 7}
# r2: 0.6295, std: 0.083 for {'max_depth': 16, 'min_samples_split': 8}
# r2: 0.6532, std: 0.048 for {'max_depth': 16, 'min_samples_split': 9}
# r2: 0.6519, std: 0.051 for {'max_depth': 16, 'min_samples_split': 10}
# r2: 0.6515, std: 0.056 for {'max_depth': 16, 'min_samples_split': 11}
# r2: 0.6658, std: 0.057 for {'max_depth': 16, 'min_samples_split': 12}
# r2: 0.6715, std: 0.060 for {'max_depth': 16, 'min_samples_split': 13}
# r2: 0.6714, std: 0.060 for {'max_depth': 16, 'min_samples_split': 14}
# r2: 0.6666, std: 0.078 for {'max_depth': 16, 'min_samples_split': 15}
# r2: 0.6733, std: 0.064 for {'max_depth': 16, 'min_samples_split': 16}
# r2: 0.6704, std: 0.059 for {'max_depth': 16, 'min_samples_split': 17}
# r2: 0.6776, std: 0.058 for {'max_depth': 16, 'min_samples_split': 18}
# r2: 0.6804, std: 0.057 for {'max_depth': 16, 'min_samples_split': 19}
# r2: 0.6800, std: 0.063 for {'max_depth': 16, 'min_samples_split': 20}
# r2: 0.6670, std: 0.059 for {'max_depth': 16, 'min_samples_split': 21}
# r2: 0.6812, std: 0.040 for {'max_depth': 16, 'min_samples_split': 22}
# r2: 0.6821, std: 0.044 for {'max_depth': 16, 'min_samples_split': 23}
# r2: 0.6829, std: 0.050 for {'max_depth': 16, 'min_samples_split': 24}
# r2: 0.6617, std: 0.065 for {'max_depth': 16, 'min_samples_split': 25}
# r2: 0.6562, std: 0.057 for {'max_depth': 16, 'min_samples_split': 26}
# r2: 0.6715, std: 0.041 for {'max_depth': 16, 'min_samples_split': 27}
# r2: 0.6520, std: 0.048 for {'max_depth': 16, 'min_samples_split': 28}
# r2: 0.6558, std: 0.054 for {'max_depth': 16, 'min_samples_split': 29}
# r2: 0.6730, std: 0.041 for {'max_depth': 16, 'min_samples_split': 30}
# r2: 0.6733, std: 0.042 for {'max_depth': 16, 'min_samples_split': 31}
# r2: 0.6273, std: 0.083 for {'max_depth': 17, 'min_samples_split': 2}
# r2: 0.6152, std: 0.104 for {'max_depth': 17, 'min_samples_split': 3}
# r2: 0.6418, std: 0.063 for {'max_depth': 17, 'min_samples_split': 4}
# r2: 0.6470, std: 0.062 for {'max_depth': 17, 'min_samples_split': 5}
# r2: 0.6380, std: 0.059 for {'max_depth': 17, 'min_samples_split': 6}
# r2: 0.6380, std: 0.059 for {'max_depth': 17, 'min_samples_split': 7}
# r2: 0.6486, std: 0.060 for {'max_depth': 17, 'min_samples_split': 8}
# r2: 0.6555, std: 0.054 for {'max_depth': 17, 'min_samples_split': 9}
# r2: 0.6557, std: 0.064 for {'max_depth': 17, 'min_samples_split': 10}
# r2: 0.6512, std: 0.049 for {'max_depth': 17, 'min_samples_split': 11}
# r2: 0.6549, std: 0.085 for {'max_depth': 17, 'min_samples_split': 12}
# r2: 0.6689, std: 0.063 for {'max_depth': 17, 'min_samples_split': 13}
# r2: 0.6665, std: 0.056 for {'max_depth': 17, 'min_samples_split': 14}
# r2: 0.6754, std: 0.051 for {'max_depth': 17, 'min_samples_split': 15}
# r2: 0.6679, std: 0.060 for {'max_depth': 17, 'min_samples_split': 16}
# r2: 0.6753, std: 0.057 for {'max_depth': 17, 'min_samples_split': 17}
# r2: 0.6850, std: 0.063 for {'max_depth': 17, 'min_samples_split': 18}
# r2: 0.6631, std: 0.068 for {'max_depth': 17, 'min_samples_split': 19}
# r2: 0.6778, std: 0.057 for {'max_depth': 17, 'min_samples_split': 20}
# r2: 0.6859, std: 0.048 for {'max_depth': 17, 'min_samples_split': 21}
# r2: 0.6857, std: 0.047 for {'max_depth': 17, 'min_samples_split': 22}
# r2: 0.6772, std: 0.037 for {'max_depth': 17, 'min_samples_split': 23}
# r2: 0.6780, std: 0.044 for {'max_depth': 17, 'min_samples_split': 24}
# r2: 0.6739, std: 0.044 for {'max_depth': 17, 'min_samples_split': 25}
# r2: 0.6753, std: 0.051 for {'max_depth': 17, 'min_samples_split': 26}
# r2: 0.6762, std: 0.048 for {'max_depth': 17, 'min_samples_split': 27}
# r2: 0.6690, std: 0.039 for {'max_depth': 17, 'min_samples_split': 28}
# r2: 0.6729, std: 0.044 for {'max_depth': 17, 'min_samples_split': 29}
# r2: 0.6729, std: 0.041 for {'max_depth': 17, 'min_samples_split': 30}
# r2: 0.6687, std: 0.035 for {'max_depth': 17, 'min_samples_split': 31}
# r2: 0.6224, std: 0.077 for {'max_depth': 18, 'min_samples_split': 2}
# r2: 0.6197, std: 0.072 for {'max_depth': 18, 'min_samples_split': 3}
# r2: 0.6212, std: 0.081 for {'max_depth': 18, 'min_samples_split': 4}
# r2: 0.6453, std: 0.061 for {'max_depth': 18, 'min_samples_split': 5}
# r2: 0.6247, std: 0.059 for {'max_depth': 18, 'min_samples_split': 6}
# r2: 0.6227, std: 0.089 for {'max_depth': 18, 'min_samples_split': 7}
# r2: 0.6303, std: 0.083 for {'max_depth': 18, 'min_samples_split': 8}
# r2: 0.6313, std: 0.075 for {'max_depth': 18, 'min_samples_split': 9}
# r2: 0.6578, std: 0.067 for {'max_depth': 18, 'min_samples_split': 10}
# r2: 0.6369, std: 0.084 for {'max_depth': 18, 'min_samples_split': 11}
# r2: 0.6706, std: 0.057 for {'max_depth': 18, 'min_samples_split': 12}
# r2: 0.6537, std: 0.090 for {'max_depth': 18, 'min_samples_split': 13}
# r2: 0.6554, std: 0.086 for {'max_depth': 18, 'min_samples_split': 14}
# r2: 0.6787, std: 0.047 for {'max_depth': 18, 'min_samples_split': 15}
# r2: 0.6687, std: 0.061 for {'max_depth': 18, 'min_samples_split': 16}
# r2: 0.6539, std: 0.071 for {'max_depth': 18, 'min_samples_split': 17}
# r2: 0.6777, std: 0.058 for {'max_depth': 18, 'min_samples_split': 18}
# r2: 0.6849, std: 0.062 for {'max_depth': 18, 'min_samples_split': 19}
# r2: 0.6654, std: 0.076 for {'max_depth': 18, 'min_samples_split': 20}
# r2: 0.6812, std: 0.042 for {'max_depth': 18, 'min_samples_split': 21}
# r2: 0.6639, std: 0.059 for {'max_depth': 18, 'min_samples_split': 22}
# r2: 0.6772, std: 0.037 for {'max_depth': 18, 'min_samples_split': 23}
# r2: 0.6780, std: 0.044 for {'max_depth': 18, 'min_samples_split': 24}
# r2: 0.6786, std: 0.051 for {'max_depth': 18, 'min_samples_split': 25}
# r2: 0.6562, std: 0.057 for {'max_depth': 18, 'min_samples_split': 26}
# r2: 0.6716, std: 0.041 for {'max_depth': 18, 'min_samples_split': 27}
# r2: 0.6664, std: 0.038 for {'max_depth': 18, 'min_samples_split': 28}
# r2: 0.6728, std: 0.044 for {'max_depth': 18, 'min_samples_split': 29}
# r2: 0.6710, std: 0.036 for {'max_depth': 18, 'min_samples_split': 30}
# r2: 0.6713, std: 0.036 for {'max_depth': 18, 'min_samples_split': 31}
# r2: 0.6178, std: 0.069 for {'max_depth': 19, 'min_samples_split': 2}
# r2: 0.6167, std: 0.099 for {'max_depth': 19, 'min_samples_split': 3}
# r2: 0.6231, std: 0.067 for {'max_depth': 19, 'min_samples_split': 4}
# r2: 0.6514, std: 0.067 for {'max_depth': 19, 'min_samples_split': 5}
# r2: 0.6427, std: 0.057 for {'max_depth': 19, 'min_samples_split': 6}
# r2: 0.6242, std: 0.091 for {'max_depth': 19, 'min_samples_split': 7}
# r2: 0.6347, std: 0.086 for {'max_depth': 19, 'min_samples_split': 8}
# r2: 0.6560, std: 0.055 for {'max_depth': 19, 'min_samples_split': 9}
# r2: 0.6548, std: 0.060 for {'max_depth': 19, 'min_samples_split': 10}
# r2: 0.6546, std: 0.057 for {'max_depth': 19, 'min_samples_split': 11}
# r2: 0.6495, std: 0.081 for {'max_depth': 19, 'min_samples_split': 12}
# r2: 0.6490, std: 0.087 for {'max_depth': 19, 'min_samples_split': 13}
# r2: 0.6722, std: 0.058 for {'max_depth': 19, 'min_samples_split': 14}
# r2: 0.6822, std: 0.050 for {'max_depth': 19, 'min_samples_split': 15}
# r2: 0.6635, std: 0.065 for {'max_depth': 19, 'min_samples_split': 16}
# r2: 0.6690, std: 0.055 for {'max_depth': 19, 'min_samples_split': 17}
# r2: 0.6852, std: 0.063 for {'max_depth': 19, 'min_samples_split': 18}
# r2: 0.6802, std: 0.057 for {'max_depth': 19, 'min_samples_split': 19}
# r2: 0.6825, std: 0.062 for {'max_depth': 19, 'min_samples_split': 20}
# r2: 0.6668, std: 0.059 for {'max_depth': 19, 'min_samples_split': 21}
# r2: 0.6856, std: 0.047 for {'max_depth': 19, 'min_samples_split': 22}
# r2: 0.6792, std: 0.045 for {'max_depth': 19, 'min_samples_split': 23}
# r2: 0.6780, std: 0.044 for {'max_depth': 19, 'min_samples_split': 24}
# r2: 0.6740, std: 0.044 for {'max_depth': 19, 'min_samples_split': 25}
# r2: 0.6562, std: 0.057 for {'max_depth': 19, 'min_samples_split': 26}
# r2: 0.6715, std: 0.041 for {'max_depth': 19, 'min_samples_split': 27}
# r2: 0.6520, std: 0.048 for {'max_depth': 19, 'min_samples_split': 28}
# r2: 0.6729, std: 0.044 for {'max_depth': 19, 'min_samples_split': 29}
# r2: 0.6729, std: 0.041 for {'max_depth': 19, 'min_samples_split': 30}
# r2: 0.6760, std: 0.042 for {'max_depth': 19, 'min_samples_split': 31}
# r2: 0.6053, std: 0.078 for {'max_depth': 20, 'min_samples_split': 2}
# r2: 0.6312, std: 0.074 for {'max_depth': 20, 'min_samples_split': 3}
# r2: 0.6242, std: 0.101 for {'max_depth': 20, 'min_samples_split': 4}
# r2: 0.6433, std: 0.073 for {'max_depth': 20, 'min_samples_split': 5}
# r2: 0.6299, std: 0.054 for {'max_depth': 20, 'min_samples_split': 6}
# r2: 0.6372, std: 0.052 for {'max_depth': 20, 'min_samples_split': 7}
# r2: 0.6562, std: 0.067 for {'max_depth': 20, 'min_samples_split': 8}
# r2: 0.6505, std: 0.051 for {'max_depth': 20, 'min_samples_split': 9}
# r2: 0.6527, std: 0.060 for {'max_depth': 20, 'min_samples_split': 10}
# r2: 0.6553, std: 0.051 for {'max_depth': 20, 'min_samples_split': 11}
# r2: 0.6675, std: 0.055 for {'max_depth': 20, 'min_samples_split': 12}
# r2: 0.6559, std: 0.088 for {'max_depth': 20, 'min_samples_split': 13}
# r2: 0.6494, std: 0.085 for {'max_depth': 20, 'min_samples_split': 14}
# r2: 0.6834, std: 0.051 for {'max_depth': 20, 'min_samples_split': 15}
# r2: 0.6511, std: 0.082 for {'max_depth': 20, 'min_samples_split': 16}
# r2: 0.6754, std: 0.057 for {'max_depth': 20, 'min_samples_split': 17}
# r2: 0.6796, std: 0.057 for {'max_depth': 20, 'min_samples_split': 18}
# r2: 0.6775, std: 0.058 for {'max_depth': 20, 'min_samples_split': 19}
# r2: 0.6607, std: 0.070 for {'max_depth': 20, 'min_samples_split': 20}
# r2: 0.6812, std: 0.042 for {'max_depth': 20, 'min_samples_split': 21}
# r2: 0.6685, std: 0.064 for {'max_depth': 20, 'min_samples_split': 22}
# r2: 0.6819, std: 0.044 for {'max_depth': 20, 'min_samples_split': 23}
# r2: 0.6801, std: 0.051 for {'max_depth': 20, 'min_samples_split': 24}
# r2: 0.6569, std: 0.058 for {'max_depth': 20, 'min_samples_split': 25}
# r2: 0.6754, std: 0.051 for {'max_depth': 20, 'min_samples_split': 26}
# r2: 0.6762, std: 0.048 for {'max_depth': 20, 'min_samples_split': 27}
# r2: 0.6691, std: 0.039 for {'max_depth': 20, 'min_samples_split': 28}
# r2: 0.6702, std: 0.044 for {'max_depth': 20, 'min_samples_split': 29}
# r2: 0.6539, std: 0.045 for {'max_depth': 20, 'min_samples_split': 30}
# r2: 0.6760, std: 0.042 for {'max_depth': 20, 'min_samples_split': 31}
# r2: 0.6047, std: 0.066 for {'max_depth': 21, 'min_samples_split': 2}
# r2: 0.6042, std: 0.096 for {'max_depth': 21, 'min_samples_split': 3}
# r2: 0.6133, std: 0.100 for {'max_depth': 21, 'min_samples_split': 4}
# r2: 0.6377, std: 0.067 for {'max_depth': 21, 'min_samples_split': 5}
# r2: 0.6345, std: 0.056 for {'max_depth': 21, 'min_samples_split': 6}
# r2: 0.6410, std: 0.066 for {'max_depth': 21, 'min_samples_split': 7}
# r2: 0.6504, std: 0.062 for {'max_depth': 21, 'min_samples_split': 8}
# r2: 0.6523, std: 0.052 for {'max_depth': 21, 'min_samples_split': 9}
# r2: 0.6338, std: 0.076 for {'max_depth': 21, 'min_samples_split': 10}
# r2: 0.6507, std: 0.049 for {'max_depth': 21, 'min_samples_split': 11}
# r2: 0.6698, std: 0.062 for {'max_depth': 21, 'min_samples_split': 12}
# r2: 0.6635, std: 0.059 for {'max_depth': 21, 'min_samples_split': 13}
# r2: 0.6498, std: 0.082 for {'max_depth': 21, 'min_samples_split': 14}
# r2: 0.6834, std: 0.051 for {'max_depth': 21, 'min_samples_split': 15}
# r2: 0.6687, std: 0.061 for {'max_depth': 21, 'min_samples_split': 16}
# r2: 0.6737, std: 0.058 for {'max_depth': 21, 'min_samples_split': 17}
# r2: 0.6806, std: 0.058 for {'max_depth': 21, 'min_samples_split': 18}
# r2: 0.6848, std: 0.062 for {'max_depth': 21, 'min_samples_split': 19}
# r2: 0.6751, std: 0.058 for {'max_depth': 21, 'min_samples_split': 20}
# r2: 0.6885, std: 0.046 for {'max_depth': 21, 'min_samples_split': 21}
# r2: 0.6856, std: 0.047 for {'max_depth': 21, 'min_samples_split': 22}
# r2: 0.6793, std: 0.045 for {'max_depth': 21, 'min_samples_split': 23}
# r2: 0.6656, std: 0.065 for {'max_depth': 21, 'min_samples_split': 24}
# r2: 0.6739, std: 0.044 for {'max_depth': 21, 'min_samples_split': 25}
# r2: 0.6609, std: 0.064 for {'max_depth': 21, 'min_samples_split': 26}
# r2: 0.6762, std: 0.048 for {'max_depth': 21, 'min_samples_split': 27}
# r2: 0.6520, std: 0.048 for {'max_depth': 21, 'min_samples_split': 28}
# r2: 0.6511, std: 0.047 for {'max_depth': 21, 'min_samples_split': 29}
# r2: 0.6757, std: 0.041 for {'max_depth': 21, 'min_samples_split': 30}
# r2: 0.6543, std: 0.045 for {'max_depth': 21, 'min_samples_split': 31}

# %%
y_pred = clf.predict(X_test)
r2_test = clf.score(X_test, y_test)
abs_test = abserr(y_pred, y_test)
print(r2_test, abs_test)
x0 = np.linspace(-2, 25, 100)
plt.plot(x0, x0, 'r')
plt.scatter(y_test, y_pred)

test_data['DTR'] = y_pred
# Out:
# 0.736530801246 2.0384341945

# %%
clf = DecisionTreeRegressor(max_depth=7, min_samples_split=50)
clf.fit(X, y)
y_pred = clf.predict(X_test)
r2_test = clf.score(X_test, y_test)
abs_test = abserr(y_pred, y_test)
print(r2_test, abs_test)
x0 = np.linspace(-2, 25, 100)
plt.plot(x0, x0, 'r')
plt.scatter(y_test, y_pred)
test_data['DTR'] = y_pred
# Out:
# 0.797196627352 1.77409116678

# %%
clf = GradientBoostingRegressor(random_state=38)

######## Range ########
n_range = np.linspace(10, 290, 15, dtype=int)
learn = np.linspace(0.01, 0.29, 15)
######## Param #########
tuned_parameters_1 = dict(learning_rate=learn, n_estimators=n_range)


clf = GridSearchCV(estimator=clf, param_grid=tuned_parameters_1, cv=cv, n_jobs=-1)
clf.fit(X_train, y_train)

print("The best parameters are %s with a score of %0.5f, test_score: %0.5f" % (clf.best_params_, clf.best_score_, clf.score(X_test, y_test)))
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("r2: %0.4f, std: %0.03f for %r" % (mean, std, params))
print()
# Out:
# The best parameters are {'learning_rate': 0.14999999999999999, 'n_estimators': 50} with a score of 0.75008, test_score: 0.80319
#
# {'learning_rate': 0.14999999999999999, 'n_estimators': 50}
#
# Grid scores on development set:
#
# r2: 0.0923, std: 0.045 for {'learning_rate': 0.01, 'n_estimators': 10}
# r2: 0.2908, std: 0.055 for {'learning_rate': 0.01, 'n_estimators': 30}
# r2: 0.4291, std: 0.062 for {'learning_rate': 0.01, 'n_estimators': 50}
# r2: 0.5236, std: 0.064 for {'learning_rate': 0.01, 'n_estimators': 70}
# r2: 0.5869, std: 0.063 for {'learning_rate': 0.01, 'n_estimators': 90}
# r2: 0.6293, std: 0.061 for {'learning_rate': 0.01, 'n_estimators': 110}
# r2: 0.6586, std: 0.058 for {'learning_rate': 0.01, 'n_estimators': 130}
# r2: 0.6786, std: 0.056 for {'learning_rate': 0.01, 'n_estimators': 150}
# r2: 0.6927, std: 0.054 for {'learning_rate': 0.01, 'n_estimators': 170}
# r2: 0.7032, std: 0.052 for {'learning_rate': 0.01, 'n_estimators': 190}
# r2: 0.7110, std: 0.050 for {'learning_rate': 0.01, 'n_estimators': 210}
# r2: 0.7167, std: 0.049 for {'learning_rate': 0.01, 'n_estimators': 230}
# r2: 0.7211, std: 0.048 for {'learning_rate': 0.01, 'n_estimators': 250}
# r2: 0.7250, std: 0.046 for {'learning_rate': 0.01, 'n_estimators': 270}
# r2: 0.7288, std: 0.045 for {'learning_rate': 0.01, 'n_estimators': 290}
# r2: 0.2927, std: 0.054 for {'learning_rate': 0.029999999999999999, 'n_estimators': 10}
# r2: 0.5892, std: 0.062 for {'learning_rate': 0.029999999999999999, 'n_estimators': 30}
# r2: 0.6801, std: 0.055 for {'learning_rate': 0.029999999999999999, 'n_estimators': 50}
# r2: 0.7117, std: 0.049 for {'learning_rate': 0.029999999999999999, 'n_estimators': 70}
# r2: 0.7251, std: 0.045 for {'learning_rate': 0.029999999999999999, 'n_estimators': 90}
# r2: 0.7344, std: 0.044 for {'learning_rate': 0.029999999999999999, 'n_estimators': 110}
# r2: 0.7381, std: 0.043 for {'learning_rate': 0.029999999999999999, 'n_estimators': 130}
# r2: 0.7415, std: 0.042 for {'learning_rate': 0.029999999999999999, 'n_estimators': 150}
# r2: 0.7448, std: 0.040 for {'learning_rate': 0.029999999999999999, 'n_estimators': 170}
# r2: 0.7463, std: 0.039 for {'learning_rate': 0.029999999999999999, 'n_estimators': 190}
# r2: 0.7481, std: 0.038 for {'learning_rate': 0.029999999999999999, 'n_estimators': 210}
# r2: 0.7486, std: 0.038 for {'learning_rate': 0.029999999999999999, 'n_estimators': 230}
# r2: 0.7496, std: 0.037 for {'learning_rate': 0.029999999999999999, 'n_estimators': 250}
# r2: 0.7491, std: 0.036 for {'learning_rate': 0.029999999999999999, 'n_estimators': 270}
# r2: 0.7487, std: 0.035 for {'learning_rate': 0.029999999999999999, 'n_estimators': 290}
# r2: 0.4349, std: 0.061 for {'learning_rate': 0.049999999999999996, 'n_estimators': 10}
# r2: 0.6827, std: 0.055 for {'learning_rate': 0.049999999999999996, 'n_estimators': 30}
# r2: 0.7231, std: 0.046 for {'learning_rate': 0.049999999999999996, 'n_estimators': 50}
# r2: 0.7366, std: 0.043 for {'learning_rate': 0.049999999999999996, 'n_estimators': 70}
# r2: 0.7420, std: 0.041 for {'learning_rate': 0.049999999999999996, 'n_estimators': 90}
# r2: 0.7444, std: 0.039 for {'learning_rate': 0.049999999999999996, 'n_estimators': 110}
# r2: 0.7485, std: 0.037 for {'learning_rate': 0.049999999999999996, 'n_estimators': 130}
# r2: 0.7496, std: 0.036 for {'learning_rate': 0.049999999999999996, 'n_estimators': 150}
# r2: 0.7493, std: 0.035 for {'learning_rate': 0.049999999999999996, 'n_estimators': 170}
# r2: 0.7486, std: 0.034 for {'learning_rate': 0.049999999999999996, 'n_estimators': 190}
# r2: 0.7483, std: 0.032 for {'learning_rate': 0.049999999999999996, 'n_estimators': 210}
# r2: 0.7479, std: 0.030 for {'learning_rate': 0.049999999999999996, 'n_estimators': 230}
# r2: 0.7464, std: 0.029 for {'learning_rate': 0.049999999999999996, 'n_estimators': 250}
# r2: 0.7438, std: 0.028 for {'learning_rate': 0.049999999999999996, 'n_estimators': 270}
# r2: 0.7424, std: 0.027 for {'learning_rate': 0.049999999999999996, 'n_estimators': 290}
# r2: 0.5321, std: 0.063 for {'learning_rate': 0.069999999999999993, 'n_estimators': 10}
# r2: 0.7109, std: 0.049 for {'learning_rate': 0.069999999999999993, 'n_estimators': 30}
# r2: 0.7350, std: 0.045 for {'learning_rate': 0.069999999999999993, 'n_estimators': 50}
# r2: 0.7441, std: 0.041 for {'learning_rate': 0.069999999999999993, 'n_estimators': 70}
# r2: 0.7481, std: 0.038 for {'learning_rate': 0.069999999999999993, 'n_estimators': 90}
# r2: 0.7487, std: 0.035 for {'learning_rate': 0.069999999999999993, 'n_estimators': 110}
# r2: 0.7462, std: 0.034 for {'learning_rate': 0.069999999999999993, 'n_estimators': 130}
# r2: 0.7451, std: 0.033 for {'learning_rate': 0.069999999999999993, 'n_estimators': 150}
# r2: 0.7430, std: 0.031 for {'learning_rate': 0.069999999999999993, 'n_estimators': 170}
# r2: 0.7412, std: 0.031 for {'learning_rate': 0.069999999999999993, 'n_estimators': 190}
# r2: 0.7406, std: 0.031 for {'learning_rate': 0.069999999999999993, 'n_estimators': 210}
# r2: 0.7385, std: 0.031 for {'learning_rate': 0.069999999999999993, 'n_estimators': 230}
# r2: 0.7382, std: 0.031 for {'learning_rate': 0.069999999999999993, 'n_estimators': 250}
# r2: 0.7366, std: 0.032 for {'learning_rate': 0.069999999999999993, 'n_estimators': 270}
# r2: 0.7353, std: 0.031 for {'learning_rate': 0.069999999999999993, 'n_estimators': 290}
# r2: 0.5964, std: 0.062 for {'learning_rate': 0.089999999999999983, 'n_estimators': 10}
# r2: 0.7228, std: 0.046 for {'learning_rate': 0.089999999999999983, 'n_estimators': 30}
# r2: 0.7383, std: 0.038 for {'learning_rate': 0.089999999999999983, 'n_estimators': 50}
# r2: 0.7388, std: 0.034 for {'learning_rate': 0.089999999999999983, 'n_estimators': 70}
# r2: 0.7427, std: 0.032 for {'learning_rate': 0.089999999999999983, 'n_estimators': 90}
# r2: 0.7417, std: 0.028 for {'learning_rate': 0.089999999999999983, 'n_estimators': 110}
# r2: 0.7427, std: 0.025 for {'learning_rate': 0.089999999999999983, 'n_estimators': 130}
# r2: 0.7398, std: 0.026 for {'learning_rate': 0.089999999999999983, 'n_estimators': 150}
# r2: 0.7380, std: 0.024 for {'learning_rate': 0.089999999999999983, 'n_estimators': 170}
# r2: 0.7378, std: 0.024 for {'learning_rate': 0.089999999999999983, 'n_estimators': 190}
# r2: 0.7376, std: 0.022 for {'learning_rate': 0.089999999999999983, 'n_estimators': 210}
# r2: 0.7362, std: 0.022 for {'learning_rate': 0.089999999999999983, 'n_estimators': 230}
# r2: 0.7325, std: 0.023 for {'learning_rate': 0.089999999999999983, 'n_estimators': 250}
# r2: 0.7302, std: 0.023 for {'learning_rate': 0.089999999999999983, 'n_estimators': 270}
# r2: 0.7263, std: 0.023 for {'learning_rate': 0.089999999999999983, 'n_estimators': 290}
# r2: 0.6394, std: 0.057 for {'learning_rate': 0.10999999999999997, 'n_estimators': 10}
# r2: 0.7312, std: 0.040 for {'learning_rate': 0.10999999999999997, 'n_estimators': 30}
# r2: 0.7456, std: 0.037 for {'learning_rate': 0.10999999999999997, 'n_estimators': 50}
# r2: 0.7465, std: 0.032 for {'learning_rate': 0.10999999999999997, 'n_estimators': 70}
# r2: 0.7455, std: 0.029 for {'learning_rate': 0.10999999999999997, 'n_estimators': 90}
# r2: 0.7406, std: 0.028 for {'learning_rate': 0.10999999999999997, 'n_estimators': 110}
# r2: 0.7407, std: 0.027 for {'learning_rate': 0.10999999999999997, 'n_estimators': 130}
# r2: 0.7402, std: 0.028 for {'learning_rate': 0.10999999999999997, 'n_estimators': 150}
# r2: 0.7350, std: 0.029 for {'learning_rate': 0.10999999999999997, 'n_estimators': 170}
# r2: 0.7322, std: 0.029 for {'learning_rate': 0.10999999999999997, 'n_estimators': 190}
# r2: 0.7298, std: 0.030 for {'learning_rate': 0.10999999999999997, 'n_estimators': 210}
# r2: 0.7275, std: 0.032 for {'learning_rate': 0.10999999999999997, 'n_estimators': 230}
# r2: 0.7260, std: 0.031 for {'learning_rate': 0.10999999999999997, 'n_estimators': 250}
# r2: 0.7244, std: 0.031 for {'learning_rate': 0.10999999999999997, 'n_estimators': 270}
# r2: 0.7219, std: 0.031 for {'learning_rate': 0.10999999999999997, 'n_estimators': 290}
# r2: 0.6683, std: 0.056 for {'learning_rate': 0.12999999999999998, 'n_estimators': 10}
# r2: 0.7365, std: 0.040 for {'learning_rate': 0.12999999999999998, 'n_estimators': 30}
# r2: 0.7452, std: 0.031 for {'learning_rate': 0.12999999999999998, 'n_estimators': 50}
# r2: 0.7470, std: 0.029 for {'learning_rate': 0.12999999999999998, 'n_estimators': 70}
# r2: 0.7460, std: 0.024 for {'learning_rate': 0.12999999999999998, 'n_estimators': 90}
# r2: 0.7418, std: 0.023 for {'learning_rate': 0.12999999999999998, 'n_estimators': 110}
# r2: 0.7388, std: 0.022 for {'learning_rate': 0.12999999999999998, 'n_estimators': 130}
# r2: 0.7336, std: 0.020 for {'learning_rate': 0.12999999999999998, 'n_estimators': 150}
# r2: 0.7301, std: 0.022 for {'learning_rate': 0.12999999999999998, 'n_estimators': 170}
# r2: 0.7288, std: 0.021 for {'learning_rate': 0.12999999999999998, 'n_estimators': 190}
# r2: 0.7251, std: 0.020 for {'learning_rate': 0.12999999999999998, 'n_estimators': 210}
# r2: 0.7202, std: 0.019 for {'learning_rate': 0.12999999999999998, 'n_estimators': 230}
# r2: 0.7172, std: 0.020 for {'learning_rate': 0.12999999999999998, 'n_estimators': 250}
# r2: 0.7150, std: 0.022 for {'learning_rate': 0.12999999999999998, 'n_estimators': 270}
# r2: 0.7131, std: 0.021 for {'learning_rate': 0.12999999999999998, 'n_estimators': 290}
# r2: 0.6894, std: 0.052 for {'learning_rate': 0.14999999999999999, 'n_estimators': 10}
# r2: 0.7411, std: 0.038 for {'learning_rate': 0.14999999999999999, 'n_estimators': 30}
# r2: 0.7501, std: 0.034 for {'learning_rate': 0.14999999999999999, 'n_estimators': 50}
# r2: 0.7481, std: 0.027 for {'learning_rate': 0.14999999999999999, 'n_estimators': 70}
# r2: 0.7436, std: 0.024 for {'learning_rate': 0.14999999999999999, 'n_estimators': 90}
# r2: 0.7395, std: 0.025 for {'learning_rate': 0.14999999999999999, 'n_estimators': 110}
# r2: 0.7364, std: 0.024 for {'learning_rate': 0.14999999999999999, 'n_estimators': 130}
# r2: 0.7319, std: 0.023 for {'learning_rate': 0.14999999999999999, 'n_estimators': 150}
# r2: 0.7266, std: 0.023 for {'learning_rate': 0.14999999999999999, 'n_estimators': 170}
# r2: 0.7242, std: 0.025 for {'learning_rate': 0.14999999999999999, 'n_estimators': 190}
# r2: 0.7202, std: 0.027 for {'learning_rate': 0.14999999999999999, 'n_estimators': 210}
# r2: 0.7186, std: 0.027 for {'learning_rate': 0.14999999999999999, 'n_estimators': 230}
# r2: 0.7162, std: 0.027 for {'learning_rate': 0.14999999999999999, 'n_estimators': 250}
# r2: 0.7139, std: 0.026 for {'learning_rate': 0.14999999999999999, 'n_estimators': 270}
# r2: 0.7122, std: 0.025 for {'learning_rate': 0.14999999999999999, 'n_estimators': 290}
# r2: 0.7008, std: 0.048 for {'learning_rate': 0.16999999999999998, 'n_estimators': 10}
# r2: 0.7397, std: 0.033 for {'learning_rate': 0.16999999999999998, 'n_estimators': 30}
# r2: 0.7468, std: 0.028 for {'learning_rate': 0.16999999999999998, 'n_estimators': 50}
# r2: 0.7484, std: 0.025 for {'learning_rate': 0.16999999999999998, 'n_estimators': 70}
# r2: 0.7384, std: 0.028 for {'learning_rate': 0.16999999999999998, 'n_estimators': 90}
# r2: 0.7352, std: 0.025 for {'learning_rate': 0.16999999999999998, 'n_estimators': 110}
# r2: 0.7330, std: 0.025 for {'learning_rate': 0.16999999999999998, 'n_estimators': 130}
# r2: 0.7275, std: 0.023 for {'learning_rate': 0.16999999999999998, 'n_estimators': 150}
# r2: 0.7214, std: 0.023 for {'learning_rate': 0.16999999999999998, 'n_estimators': 170}
# r2: 0.7171, std: 0.023 for {'learning_rate': 0.16999999999999998, 'n_estimators': 190}
# r2: 0.7146, std: 0.021 for {'learning_rate': 0.16999999999999998, 'n_estimators': 210}
# r2: 0.7110, std: 0.020 for {'learning_rate': 0.16999999999999998, 'n_estimators': 230}
# r2: 0.7071, std: 0.021 for {'learning_rate': 0.16999999999999998, 'n_estimators': 250}
# r2: 0.7049, std: 0.020 for {'learning_rate': 0.16999999999999998, 'n_estimators': 270}
# r2: 0.7023, std: 0.020 for {'learning_rate': 0.16999999999999998, 'n_estimators': 290}
# r2: 0.7087, std: 0.049 for {'learning_rate': 0.18999999999999997, 'n_estimators': 10}
# r2: 0.7394, std: 0.039 for {'learning_rate': 0.18999999999999997, 'n_estimators': 30}
# r2: 0.7394, std: 0.034 for {'learning_rate': 0.18999999999999997, 'n_estimators': 50}
# r2: 0.7370, std: 0.026 for {'learning_rate': 0.18999999999999997, 'n_estimators': 70}
# r2: 0.7318, std: 0.025 for {'learning_rate': 0.18999999999999997, 'n_estimators': 90}
# r2: 0.7283, std: 0.025 for {'learning_rate': 0.18999999999999997, 'n_estimators': 110}
# r2: 0.7240, std: 0.024 for {'learning_rate': 0.18999999999999997, 'n_estimators': 130}
# r2: 0.7200, std: 0.022 for {'learning_rate': 0.18999999999999997, 'n_estimators': 150}
# r2: 0.7189, std: 0.023 for {'learning_rate': 0.18999999999999997, 'n_estimators': 170}
# r2: 0.7119, std: 0.021 for {'learning_rate': 0.18999999999999997, 'n_estimators': 190}
# r2: 0.7088, std: 0.020 for {'learning_rate': 0.18999999999999997, 'n_estimators': 210}
# r2: 0.7054, std: 0.019 for {'learning_rate': 0.18999999999999997, 'n_estimators': 230}
# r2: 0.7028, std: 0.018 for {'learning_rate': 0.18999999999999997, 'n_estimators': 250}
# r2: 0.6988, std: 0.018 for {'learning_rate': 0.18999999999999997, 'n_estimators': 270}
# r2: 0.6973, std: 0.018 for {'learning_rate': 0.18999999999999997, 'n_estimators': 290}
# r2: 0.7172, std: 0.044 for {'learning_rate': 0.20999999999999996, 'n_estimators': 10}
# r2: 0.7422, std: 0.033 for {'learning_rate': 0.20999999999999996, 'n_estimators': 30}
# r2: 0.7412, std: 0.027 for {'learning_rate': 0.20999999999999996, 'n_estimators': 50}
# r2: 0.7344, std: 0.021 for {'learning_rate': 0.20999999999999996, 'n_estimators': 70}
# r2: 0.7266, std: 0.022 for {'learning_rate': 0.20999999999999996, 'n_estimators': 90}
# r2: 0.7203, std: 0.023 for {'learning_rate': 0.20999999999999996, 'n_estimators': 110}
# r2: 0.7194, std: 0.022 for {'learning_rate': 0.20999999999999996, 'n_estimators': 130}
# r2: 0.7165, std: 0.024 for {'learning_rate': 0.20999999999999996, 'n_estimators': 150}
# r2: 0.7113, std: 0.025 for {'learning_rate': 0.20999999999999996, 'n_estimators': 170}
# r2: 0.7084, std: 0.028 for {'learning_rate': 0.20999999999999996, 'n_estimators': 190}
# r2: 0.7028, std: 0.028 for {'learning_rate': 0.20999999999999996, 'n_estimators': 210}
# r2: 0.7004, std: 0.030 for {'learning_rate': 0.20999999999999996, 'n_estimators': 230}
# r2: 0.6976, std: 0.029 for {'learning_rate': 0.20999999999999996, 'n_estimators': 250}
# r2: 0.6947, std: 0.028 for {'learning_rate': 0.20999999999999996, 'n_estimators': 270}
# r2: 0.6928, std: 0.029 for {'learning_rate': 0.20999999999999996, 'n_estimators': 290}
# r2: 0.7212, std: 0.045 for {'learning_rate': 0.22999999999999998, 'n_estimators': 10}
# r2: 0.7433, std: 0.039 for {'learning_rate': 0.22999999999999998, 'n_estimators': 30}
# r2: 0.7372, std: 0.038 for {'learning_rate': 0.22999999999999998, 'n_estimators': 50}
# r2: 0.7352, std: 0.031 for {'learning_rate': 0.22999999999999998, 'n_estimators': 70}
# r2: 0.7282, std: 0.022 for {'learning_rate': 0.22999999999999998, 'n_estimators': 90}
# r2: 0.7246, std: 0.024 for {'learning_rate': 0.22999999999999998, 'n_estimators': 110}
# r2: 0.7180, std: 0.025 for {'learning_rate': 0.22999999999999998, 'n_estimators': 130}
# r2: 0.7137, std: 0.024 for {'learning_rate': 0.22999999999999998, 'n_estimators': 150}
# r2: 0.7081, std: 0.024 for {'learning_rate': 0.22999999999999998, 'n_estimators': 170}
# r2: 0.7025, std: 0.026 for {'learning_rate': 0.22999999999999998, 'n_estimators': 190}
# r2: 0.6982, std: 0.023 for {'learning_rate': 0.22999999999999998, 'n_estimators': 210}
# r2: 0.6951, std: 0.024 for {'learning_rate': 0.22999999999999998, 'n_estimators': 230}
# r2: 0.6927, std: 0.024 for {'learning_rate': 0.22999999999999998, 'n_estimators': 250}
# r2: 0.6915, std: 0.024 for {'learning_rate': 0.22999999999999998, 'n_estimators': 270}
# r2: 0.6896, std: 0.023 for {'learning_rate': 0.22999999999999998, 'n_estimators': 290}
# r2: 0.7243, std: 0.045 for {'learning_rate': 0.24999999999999997, 'n_estimators': 10}
# r2: 0.7442, std: 0.040 for {'learning_rate': 0.24999999999999997, 'n_estimators': 30}
# r2: 0.7391, std: 0.036 for {'learning_rate': 0.24999999999999997, 'n_estimators': 50}
# r2: 0.7307, std: 0.033 for {'learning_rate': 0.24999999999999997, 'n_estimators': 70}
# r2: 0.7225, std: 0.038 for {'learning_rate': 0.24999999999999997, 'n_estimators': 90}
# r2: 0.7163, std: 0.036 for {'learning_rate': 0.24999999999999997, 'n_estimators': 110}
# r2: 0.7105, std: 0.034 for {'learning_rate': 0.24999999999999997, 'n_estimators': 130}
# r2: 0.7054, std: 0.033 for {'learning_rate': 0.24999999999999997, 'n_estimators': 150}
# r2: 0.7020, std: 0.035 for {'learning_rate': 0.24999999999999997, 'n_estimators': 170}
# r2: 0.6993, std: 0.033 for {'learning_rate': 0.24999999999999997, 'n_estimators': 190}
# r2: 0.6957, std: 0.032 for {'learning_rate': 0.24999999999999997, 'n_estimators': 210}
# r2: 0.6935, std: 0.030 for {'learning_rate': 0.24999999999999997, 'n_estimators': 230}
# r2: 0.6921, std: 0.030 for {'learning_rate': 0.24999999999999997, 'n_estimators': 250}
# r2: 0.6897, std: 0.029 for {'learning_rate': 0.24999999999999997, 'n_estimators': 270}
# r2: 0.6889, std: 0.029 for {'learning_rate': 0.24999999999999997, 'n_estimators': 290}
# r2: 0.7204, std: 0.051 for {'learning_rate': 0.26999999999999996, 'n_estimators': 10}
# r2: 0.7388, std: 0.035 for {'learning_rate': 0.26999999999999996, 'n_estimators': 30}
# r2: 0.7354, std: 0.030 for {'learning_rate': 0.26999999999999996, 'n_estimators': 50}
# r2: 0.7310, std: 0.027 for {'learning_rate': 0.26999999999999996, 'n_estimators': 70}
# r2: 0.7250, std: 0.022 for {'learning_rate': 0.26999999999999996, 'n_estimators': 90}
# r2: 0.7179, std: 0.024 for {'learning_rate': 0.26999999999999996, 'n_estimators': 110}
# r2: 0.7113, std: 0.026 for {'learning_rate': 0.26999999999999996, 'n_estimators': 130}
# r2: 0.7058, std: 0.026 for {'learning_rate': 0.26999999999999996, 'n_estimators': 150}
# r2: 0.6996, std: 0.030 for {'learning_rate': 0.26999999999999996, 'n_estimators': 170}
# r2: 0.6958, std: 0.030 for {'learning_rate': 0.26999999999999996, 'n_estimators': 190}
# r2: 0.6924, std: 0.032 for {'learning_rate': 0.26999999999999996, 'n_estimators': 210}
# r2: 0.6897, std: 0.033 for {'learning_rate': 0.26999999999999996, 'n_estimators': 230}
# r2: 0.6886, std: 0.033 for {'learning_rate': 0.26999999999999996, 'n_estimators': 250}
# r2: 0.6862, std: 0.033 for {'learning_rate': 0.26999999999999996, 'n_estimators': 270}
# r2: 0.6849, std: 0.033 for {'learning_rate': 0.26999999999999996, 'n_estimators': 290}
# r2: 0.7270, std: 0.046 for {'learning_rate': 0.28999999999999998, 'n_estimators': 10}
# r2: 0.7381, std: 0.041 for {'learning_rate': 0.28999999999999998, 'n_estimators': 30}
# r2: 0.7365, std: 0.038 for {'learning_rate': 0.28999999999999998, 'n_estimators': 50}
# r2: 0.7296, std: 0.036 for {'learning_rate': 0.28999999999999998, 'n_estimators': 70}
# r2: 0.7201, std: 0.038 for {'learning_rate': 0.28999999999999998, 'n_estimators': 90}
# r2: 0.7126, std: 0.035 for {'learning_rate': 0.28999999999999998, 'n_estimators': 110}
# r2: 0.7090, std: 0.033 for {'learning_rate': 0.28999999999999998, 'n_estimators': 130}
# r2: 0.7022, std: 0.031 for {'learning_rate': 0.28999999999999998, 'n_estimators': 150}
# r2: 0.6991, std: 0.031 for {'learning_rate': 0.28999999999999998, 'n_estimators': 170}
# r2: 0.6964, std: 0.028 for {'learning_rate': 0.28999999999999998, 'n_estimators': 190}
# r2: 0.6934, std: 0.028 for {'learning_rate': 0.28999999999999998, 'n_estimators': 210}
# r2: 0.6913, std: 0.028 for {'learning_rate': 0.28999999999999998, 'n_estimators': 230}
# r2: 0.6893, std: 0.029 for {'learning_rate': 0.28999999999999998, 'n_estimators': 250}
# r2: 0.6866, std: 0.028 for {'learning_rate': 0.28999999999999998, 'n_estimators': 270}
# r2: 0.6856, std: 0.028 for {'learning_rate': 0.28999999999999998, 'n_estimators': 290}

# %%
clf = GradientBoostingRegressor(learning_rate=0.12, n_estimators=90,random_state=38)
######## Range ########
max_depth = np.linspace(2, 12, 11, dtype=int)
######## Param #########
tuned_parameters_2 = dict(max_depth=max_depth)


clf = GridSearchCV(estimator=clf, param_grid=tuned_parameters_2, cv=cv, n_jobs=-1)
clf.fit(X_train, y_train)

print("The best parameters are %s with a score of %0.5f, test_score: %0.5f" % (clf.best_params_, clf.best_score_, clf.score(X_test, y_test)))
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("r2: %0.4f, std: %0.03f for %r" % (mean, std, params))
print()
# Out:
# The best parameters are {'max_depth': 3} with a score of 0.74483, test_score: 0.80900
#
# {'max_depth': 3}
#
# Grid scores on development set:
#
# r2: 0.7419, std: 0.032 for {'max_depth': 2}
# r2: 0.7448, std: 0.030 for {'max_depth': 3}
# r2: 0.7358, std: 0.030 for {'max_depth': 4}
# r2: 0.7083, std: 0.041 for {'max_depth': 5}
# r2: 0.7021, std: 0.027 for {'max_depth': 6}
# r2: 0.6847, std: 0.045 for {'max_depth': 7}
# r2: 0.6737, std: 0.058 for {'max_depth': 8}
# r2: 0.6764, std: 0.066 for {'max_depth': 9}
# r2: 0.6592, std: 0.075 for {'max_depth': 10}
# r2: 0.6465, std: 0.074 for {'max_depth': 11}
# r2: 0.6347, std: 0.076 for {'max_depth': 12}

# %%
y_pred = clf.predict(X_test)
r2_test = clf.score(X_test, y_test)
abs_test = abserr(y_pred, y_test)
print(r2_test, abs_test)
x0 = np.linspace(-2, 25, 100)
plt.plot(x0, x0, 'r')
plt.scatter(y_test, y_pred)

test_data['GBDT'] = y_pred
# Out:
# 0.861909943235 1.28378318209

# %%
clf = GradientBoostingRegressor()
clf.fit(X, y)
y_pred = clf.predict(X_test)
r2_test = clf.score(X_test, y_test)
abs_test = abserr(y_pred, y_test)
print(r2_test, abs_test)
x0 = np.linspace(-2, 25, 100)
plt.plot(x0, x0, 'r')
plt.scatter(y_test, y_pred)
test_data['GBDT'] = y_pred
# Out:
# 0.904866906847 1.13046552166

# %%
test_data['Mesured'] = y_test
test_data.to_csv('Four_BH.csv')

# %%
def test_model(clf, x=X_train, y=y_train, randn=38):               
    r2_val_score = cross_val_score(clf, x, y, cv=cv, n_jobs=-1)   
    scores=r2_val_score.mean()
    stds=r2_val_score.std()
    return np.array([scores, stds])

# %%
results = {}

clf = LinearRegression()  
results["Linear"]=test_model(clf)  

clf = SVR(C=100)  
results["SVM RBF"]=test_model(clf) 

clf = DecisionTreeRegressor()  
results["RandomForest"]=test_model(clf) 

clf = GradientBoostingRegressor()
results["GradientBoosting"]=test_model(clf)

# %%
results1 = pd.DataFrame.from_dict(results,orient='index') 
results1.columns=['R Square Score', 'Std'] 
results1 = results1.sort_values(by='R Square Score')
#results1['Std'] = results1['Std'] * 10
results1.plot(kind="bar",title="Model Scores") 
axes = plt.gca()  
axes.set_ylim([0,1])
results1
# Out:
#                   R Square Score       Std
# SVM RBF                 0.566263  0.076657
# RandomForest            0.618683  0.074211
# Linear                  0.650819  0.049617
# GradientBoosting        0.747458  0.029174

# %%
def mater(CepRs, REs, La=0.0, Co=0.0, TM=1.0, B=6.0):
    Ce = (REs - La) * CepRs
    PrNd = REs - La - Ce
    Fe = 100.0 - PrNd - Ce - La - Co -TM - B
    PrNd_p, La_p, Ce_p = PrNd / REs, La / REs, Ce / REs
    one_mater = [REs, PrNd, La, Ce, Fe, Co, TM, B, PrNd_p, La_p, Ce_p]
    return one_mater

# %%
list_1 = []
ceprs = np.linspace(0, 1, 21)
res = np.linspace(6, 18, 21)

for i in ceprs:
    for j in res:
        list_1.append(mater(i, j))

a = np.array(list_1)
new = pd.DataFrame(a, columns=['REs', 'PrNd', 'La', 'Ce', 'Fe', 'Co', 'TM', 'B', 'PrNd_p', 'La_p', 'Ce_p'])
new.head(2)
# Out:
#    REs  PrNd   La   Ce    Fe   Co   TM    B  PrNd_p  La_p  Ce_p
# 0  6.0   6.0  0.0  0.0  87.0  0.0  1.0  6.0     1.0   0.0   0.0
# 1  6.6   6.6  0.0  0.0  86.4  0.0  1.0  6.0     1.0   0.0   0.0

# %%
new_bh = clf.predict(new.values).reshape(len(ceprs), len(res))
new_2 = pd.DataFrame(new_bh, index=ceprs, columns=res)
new_2.to_csv('preds_bh.csv')
